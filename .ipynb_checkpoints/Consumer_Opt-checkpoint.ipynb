# %% [markdown]
# # Consumer Opt. with PV

# %%
using Pkg
Pkg.activate("."); 
Pkg.instantiate()
# Out:
#   Activating project at `C:\Users\ESchr\workspace\uni\ATIS3\Single_Project\ATIES3_single_project_ES`

# %%
using JuMP, LinearAlgebra, StatsPlots, Statistics, CSV, DataFrames, XLSX, CPLEX, AxisArrays, Plots

# %% [markdown]
# ## Input handling

# %%
input_path = "input\\"
#xl = XLSX.readxlsx(input_path * "input.xlsx") 
xl = XLSX.readxlsx(input_path * "input_big.xlsx") 
data = Dict()

for s in XLSX.sheetnames(xl)
    data[s] = DataFrame(XLSX.gettable(xl[s]; infer_eltypes=true)...)
end

# %%
input_path = "input\\"
xl = XLSX.readxlsx(input_path * "solar_input.xlsx") 

for s in XLSX.sheetnames(xl)
    data[s] = DataFrame(XLSX.gettable(xl[s]; infer_eltypes=true)...)
end

# %%
input_path = "input\\"
xl = XLSX.readxlsx(input_path * "prices.xlsx") 

for s in XLSX.sheetnames(xl)
    data[s] = DataFrame(XLSX.gettable(xl[s]; infer_eltypes=true)...)
end

# %%
data
# Out:
# Dict{Any, Any} with 8 entries:
#   "NU_non_anticipativity_matrix" => 15×85 DataFrame…
#   "pv_production"                => 16×85 DataFrame…
#   "prices"                       => 8761×3 DataFrame…
#   "pool_price_scenarios"         => 16×85 DataFrame…
#   "solar_input"                  => 35043×3 DataFrame…
#   "bilateral_contract_data"      => 12×9 DataFrame…
#   "non_anticipativity_matrix"    => 15×5 DataFrame…
#   "electricity_demand"           => 1×85 DataFrame…

# %% [markdown]
# # Data handling

# %%
T = data["solar_input"][:, :Time]
FC_S = data["solar_input"][:, :FC_Solar]
Act_S = data["solar_input"][:, :Act_Solar]
H = data["prices"][:, :Hour]
TIME = data["prices"][:, :Time]
DHP = data["prices"][:, :Day_Ahead_Price]
T_NQ = length(T)

valley = [1, 2, 3, 4, 5, 6, 7, 8]
shoulder = [9, 10, 15, 16, 17, 18, 23, 0]
peak = [11, 12, 13, 14, 19, 20, 21, 22]
println("Sets created")
# Out:
# Sets created

# %%
Dsolar_input = Dict(c => AxisArray(data["solar_input"][:, c], t = 1:T_NQ) for c in names(data["solar_input"]));
Dprice = Dict(c => AxisArray(data["prices"][:, c], h = H) for c in names(data["prices"]));

# %%
#combine price and solar data with hour dependcy
h = 1
i = 1
FC_Solar = 0
Act_Solar = 0
Day_Ahead_Price = 0
Data = Dict()

for t in 1:T_NQ
    FC_Solar += Dsolar_input["FC_Solar"][t]
    Act_Solar += Dsolar_input["Act_Solar"][t]
    if(h == 4)
        if(Dprice["Hour"][i] in valley)            
            PV_Data = Dict("FC_Solar" => round((FC_Solar/4), digits = 2), "Act_Solar" => round((Act_Solar/4), digits = 2), "price" => Dprice["Day_Ahead_Price"][i], "hour" => Dprice["Hour"][i], "set" => 1)
        elseif(Dprice["Hour"][i] in shoulder) 
            PV_Data = Dict("FC_Solar" => round((FC_Solar/4), digits = 2), "Act_Solar" => round((Act_Solar/4), digits = 2), "price" => Dprice["Day_Ahead_Price"][i], "hour" => Dprice["Hour"][i], "set" => 2)
        elseif(Dprice["Hour"][i] in peak) 
            PV_Data = Dict("FC_Solar" => round((FC_Solar/4), digits = 2), "Act_Solar" => round((Act_Solar/4), digits = 2), "price" => Dprice["Day_Ahead_Price"][i], "hour" => Dprice["Hour"][i], "set" => 3)
        end
        Data[i] = PV_Data
        h = 0
        i += 1
        FC_Solar = 0
        Act_Solar = 0
    end
    h += 1
end

# %% [markdown]
# ### Create Sets and Parameters

# %%
#Sets
W_PP = data["pool_price_scenarios"][:, :Scenario]
W_NAM = data["non_anticipativity_matrix"][:, :Scenario]
B = data["bilateral_contract_data"][:, :Contract]
D = data["electricity_demand"][:, :Demand]
WEEK = ["we1", "we2", "we3", "we4"]
K = ["k1", "k2", "k3", "k4"]

T = String[]
for c in names(data["pool_price_scenarios"])
    push!(T, c)
end
T = T[2:end]

#Axis arrays
Dpool_price_scenarios = Dict(c => AxisArray(data["pool_price_scenarios"][:, c], w_pp=W_PP) for c in names(data["pool_price_scenarios"]));
Dbilateral_contract_data = Dict(c => AxisArray(data["bilateral_contract_data"][:, c], b=B) for c in names(data["bilateral_contract_data"]));
Delectricity_demand = Dict(c => AxisArray(data["electricity_demand"][:, c], d=D) for c in names(data["electricity_demand"]));
Dnon_anticipativity_matrix = Dict(c => AxisArray(data["non_anticipativity_matrix"][:, c], w_nam=W_NAM) for c in names(data["non_anticipativity_matrix"]));
Dpv_production = Dict(c => AxisArray(data["pv_production"][:, c], w_pp=W_PP) for c in names(data["pv_production"]));

#Mapping of bilateral contracts active in period T
Bt = Dict()
for week in WEEK
    temp = String[]
    for b in B
        if(Dbilateral_contract_data[week][b]==1)
            push!(temp, b)
        end
    end
    Bt[week] = temp
end 

#Mapping of decisions on bilateral contracts made in stage K
Kb = Dict()
Kb["k1"] = Bt["we1"]
Kb["k3"] = ["b7", "b8"]
Kb["k4"] = ["b9", "b10"]
Kb["k2"] = ["b12", "b11"]

#Probalitie for scenarios
prob = Dict()
for w in W_PP
    prob[w] = 1/length(W_PP)
end

#Arrays of decisions on bilateral contracts made in stage K
k1 = data["non_anticipativity_matrix"][:, :k1]
k2 = data["non_anticipativity_matrix"][:, :k2]
k3 = data["non_anticipativity_matrix"][:, :k3]
k4 = data["non_anticipativity_matrix"][:, :k4]

NW_PP = length(W_PP)

#week hour allocation 
week_to_hour = Dict()
week_to_hour["we1"] = T[1:21]
week_to_hour["we2"] = T[22:42]
week_to_hour["we3"] = T[43:63]
week_to_hour["we4"] = T[64:end]
println("Sets created")
# Out:
# Sets created

# %% [markdown]
# # Scenario Generation

# %% [markdown]
# ## Spring price scenarios
# Scenarios are calculated through the different hour blocks. Therefore there exists no direct connection between two sequential hourly periods, as we consider the scenario as an average value for the hours.

# %% [markdown]
# Auf der Nordhalbkugel - also bei uns - ist am 21. März Frühlingsanfang, am 21. Juni beginnt der Sommer, am 23. September ist Herbstanfang und am 21. Dezember Winterbeginn.

# %%
#spring starts at hour 1896 and ends at 4104
D_spring_price =  Dict()
D_spring_price1 =  Dict()
spring_price1 = Float64[]
spring_act_solar1 = Float64[]
D_spring_price2 =  Dict()
spring_price2 = Float64[]
spring_act_solar2 = Float64[]
D_spring_price3 =  Dict()
spring_price3 = Float64[]
spring_act_solar3 = Float64[]

for t in TIME[1896:4104]
    D_spring_price[t] = Data[t]
    if(Data[t]["set"]==1)
        D_spring_price1[t] = Data[t]
        push!(spring_price1, Data[t]["price"])
        push!(spring_act_solar1, Data[t]["Act_Solar"])
    elseif(Data[t]["set"]==2)
        D_spring_price2[t] = Data[t]
        push!(spring_price2, Data[t]["price"])
        push!(spring_act_solar2, Data[t]["Act_Solar"])
    elseif(Data[t]["set"]==3)
        D_spring_price3[t] = Data[t]
        push!(spring_price3, Data[t]["price"])
        push!(spring_act_solar3, Data[t]["Act_Solar"])
    end    
end

# %% [markdown]
# # Visualisation

# %%
path = raw"C:\Users\ ESchr\ workspace\ uni\ ATIS3\ Single_Project\ ATIES3_single_project_ES\ Plots\plot_ref"
# Out:
# "C:\\Users\\ ESchr\\ workspace\\ uni\\ ATIS3\\ Single_Project\\ ATIES3_single_project_ES\\ Plots\\plot_ref"

# %%
plot_ref = plot(spring_price3, x=:time, y=:price, label = "DA-price")
xlabel!("hour of the year 2021")
ylabel!("price DA in €")
#savefig("DA_price_yearly_h")

# %%
density(spring_act_solar1, label="valley solar generation spring")

# %%
density(spring_price1, label="valley day-ahead prices spring")

# %%
density(spring_act_solar2, label="Day-ahead Prices")

# %%
density(spring_price2, label="Day-ahead Prices")

# %%
density(spring_act_solar3, label="Day-ahead Prices")

# %%
density(spring_price3, label="Day-ahead Prices")

# %%
density(DHP[1, :], label="Day-ahead Prices")

# %% [markdown]
# # Model

# %%
# Risk
β = 8
α = 0.95

#Duration in hours of every period t
d = Dict()
for t in T
    d[t]=1
end

# %%
co_pv = Model(CPLEX.Optimizer)
# Out:
# A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: CPLEX

# %%
@variables(co_pv, begin
        PB[B,W_PP]            #Power purchased from bilateral contracts
        s[B,W_PP], Bin        #Selection of bilateral contracts
        EP[T,W_PP]            #Energy traded in the pool
        η[W_PP] >= 0          #Auxiliary variable used to calculate the CVaR
        ζ                     #Auxiliary variable used to calculate the CVaR
    end)
println("Variables created")
# Out:
# Variables created

# %% [markdown]
# TODO: d[t] abhängigkeit einbauen

# %%
@time begin    
    λ_B = @expression(co_pv, [week in WEEK, t in week_to_hour[week], w in W_PP, b in Bt[week]], (Dpool_price_scenarios[t][w]+Dbilateral_contract_data["price"][b])/2)
    λ_P = @expression(co_pv, [t in T, w in W_PP], Dpool_price_scenarios[t][w])     
    CVaR = @expression(co_pv, β * (ζ+(1/(1-α))*sum(prob[w]*η[w] for w in W_PP)))  
    z = @expression(co_pv, sum(prob[w] * sum(sum(sum(λ_B[week, t, w, b] * PB[b,w] * d[t] for b in Bt[week]) + λ_P[t,w] * EP[t,w] for t in  week_to_hour[week]) for week in WEEK) for w in W_PP) + CVaR)
end
println("Expressions created")
# Out:
#   0.597664 seconds (810.11 k allocations: 45.378 MiB, 90.07% compilation time)
# Expressions created

# %%
@constraints(co_pv, begin
        LimitContractMin[b in B, w in W_PP], PB[b,w] >= s[b,w] * Dbilateral_contract_data["min_power"][b]
        LimitContractMax[b in B, w in W_PP], PB[b,w] <= s[b,w] * Dbilateral_contract_data["max_power"][b]
        
        Non_Anticipativity1[b in Kb["k1"], τ in (1:NW_PP-1)[k1.== 1]], PB[b,W_PP[τ]] == PB[b, W_PP[τ+1]]
        Non_Anticipativity2[b in Kb["k2"], τ in (1:NW_PP-1)[k2.== 1]], PB[b,W_PP[τ]] == PB[b, W_PP[τ+1]]
        Non_Anticipativity3[b in Kb["k3"], τ in (1:NW_PP-1)[k3.== 1]], PB[b,W_PP[τ]] == PB[b, W_PP[τ+1]]
        Non_Anticipativity4[b in Kb["k4"], τ in (1:NW_PP-1)[k4.== 1]], PB[b,W_PP[τ]] == PB[b, W_PP[τ+1]]
        
        Arbitrage[t in T, w in W_PP], EP[t,w] >= -Dpv_production[t][w]
        EnergyBalance[week in WEEK, t in week_to_hour[week], w in W_PP], EP[t,w] + Dpv_production[t][w] + sum(PB[b,w]*d[t] for b in Bt[week]) == Delectricity_demand[t]["d1"]
        CVaRconstr[w in W_PP], sum(sum(sum(λ_B[week, t, w, b] * PB[b,w] * d[t] for b in Bt[week]) + λ_P[t,w] * EP[t,w] for t in  week_to_hour[week]) for week in WEEK) - ζ <= η[w]
        NonNeg[w in W_PP], 0 <= η[w]        
    end)
println("Constraints created")
# Out:
# Constraints created

# %%
@time begin
    @objective(co_pv, Min, z)
end
print("Objective function created")
# Out:
#   0.000469 seconds (5.91 k allocations: 238.969 KiB)
# Objective function created

# %%
@time begin
    optimize!(co_pv)
end
# Out:
# Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# 4 of 4 MIP starts provided solutions.
# MIP start 'm4' defined initial solution with objective 7656547.6596.
# Tried aggregator 2 times.
# MIP Presolve eliminated 1360 rows and 0 columns.
# Aggregator did 158 substitutions.
# Reduced MIP has 1744 rows, 1587 columns, and 11744 nonzeros.
# Reduced MIP has 192 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (12.03 ticks)
# Probing time = 0.03 sec. (11.70 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 524 rows and 366 columns.
# Reduced MIP has 1220 rows, 1221 columns, and 9448 nonzeros.
# Reduced MIP has 34 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (7.57 ticks)
# Probing time = 0.00 sec. (2.72 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.02 sec. (5.91 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                      7656547.6596                            ---
#       0     0        cutoff        7656547.6596                   1138    0.00%
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (45.96 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.08 sec. (45.96 ticks)
#   0.068561 seconds (2.98 k allocations: 73.984 KiB)

# %% [markdown]
# # Results

# %%
for w in W_PP    
    PB2 = sum(value.(PB[b,w]) for b in B)
    println(w, " = ", PB2)
end
# Out:
# w1 = 50.0
# w2 = 50.0
# w3 = 50.0
# w4 = 50.0
# w5 = 50.0
# w6 = 50.0
# w7 = 50.0
# w8 = 50.0
# w9 = 50.0
# w10 = 50.0
# w11 = 50.0
# w12 = 50.0
# w13 = 50.0
# w14 = 50.0
# w15 = 50.0
# w16 = 50.0

# %%
#prices per scenario
for w in W_PP    
    for week in WEEK        
        for b in Bt[week]
            println(w," ", week)
        for t in week_to_hour[week]
            print(b," ; λ_B = ", value(λ_B[week, t, w, b]))
            println(" ; λ_P = ", value(λ_P[t,w]))
        end
        end
        println()
    end
end
# Out:
# w1 we1
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# w1 we1
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# w1 we1
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# w1 we1
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# w1 we1
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# w1 we1
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
#
# w1 we2
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# w1 we2
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# w1 we2
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# w1 we2
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# w1 we2
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# w1 we2
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
#
# w1 we3
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# w1 we3
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# w1 we3
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# w1 we3
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# w1 we3
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# w1 we3
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
#
# w1 we4
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# w1 we4
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# w1 we4
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# w1 we4
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# w1 we4
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# b11 ; λ_B = 51.4 ; λ_P = 45
# w1 we4
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
# b12 ; λ_B = 54.7 ; λ_P = 45
#
# w2 we1
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# w2 we1
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# w2 we1
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# w2 we1
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# w2 we1
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# w2 we1
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
#
# w2 we2
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# w2 we2
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# w2 we2
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# w2 we2
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# w2 we2
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# w2 we2
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
#
# w2 we3
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# b1 ; λ_B = 49.7 ; λ_P = 45
# w2 we3
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# b2 ; λ_B = 56.55 ; λ_P = 45
# w2 we3
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# b3 ; λ_B = 50.2 ; λ_P = 45
# w2 we3
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# b4 ; λ_B = 54.55 ; λ_P = 45
# w2 we3
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# b9 ; λ_B = 51.2 ; λ_P = 45
# w2 we3
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
# b10 ; λ_B = 54.55 ; λ_P = 45
#
# w2 we4
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# w2 we4
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# w2 we4
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# w2 we4
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# w2 we4
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# w2 we4
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
#
# w3 we1
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# w3 we1
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# w3 we1
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# w3 we1
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# w3 we1
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# w3 we1
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
#
# w3 we2
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# w3 we2
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# w3 we2
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# w3 we2
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# w3 we2
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# b7 ; λ_B = 51.85 ; λ_P = 47
# w3 we2
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
# b8 ; λ_B = 55.1 ; λ_P = 47
#
# w3 we3
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# b1 ; λ_B = 50.2 ; λ_P = 46
# w3 we3
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# b2 ; λ_B = 57.05 ; λ_P = 46
# w3 we3
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# b3 ; λ_B = 50.7 ; λ_P = 46
# w3 we3
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# b4 ; λ_B = 55.05 ; λ_P = 46
# w3 we3
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# b9 ; λ_B = 51.7 ; λ_P = 46
# w3 we3
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
# b10 ; λ_B = 55.05 ; λ_P = 46
#
# w3 we4
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# w3 we4
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# w3 we4
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# w3 we4
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# w3 we4
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# b11 ; λ_B = 52.4 ; λ_P = 47
# w3 we4
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
# b12 ; λ_B = 55.7 ; λ_P = 47
#
# w4 we1
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# b1 ; λ_B = 49.2 ; λ_P = 44
# w4 we1
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# b2 ; λ_B = 56.05 ; λ_P = 44
# w4 we1
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# b3 ; λ_B = 49.7 ; λ_P = 44
# w4 we1
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# b4 ; λ_B = 54.05 ; λ_P = 44
# w4 we1
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# b5 ; λ_B = 44.95 ; λ_P = 44
# w4 we1
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
# b6 ; λ_B = 50.0 ; λ_P = 44
#
# w4 we2
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# b1 ; λ_B = 50.7 ; λ_P = 47
# w4 we2
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# b2 ; λ_B = 57.55 ; λ_P = 47
# w4 we2
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# b3 ; λ_B = 51.2 ; λ_P = 47
# w4 we2
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# b4 ; λ_B = 55.55 ; λ_P = 47
# ...
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# w15 we4
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# w15 we4
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# b11 ; λ_B = 53.9 ; λ_P = 50
# w15 we4
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
# b12 ; λ_B = 57.2 ; λ_P = 50
#
# w16 we1
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# w16 we1
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# w16 we1
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# w16 we1
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# w16 we1
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# b5 ; λ_B = 47.95 ; λ_P = 50
# w16 we1
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
# b6 ; λ_B = 53.0 ; λ_P = 50
#
# w16 we2
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# b1 ; λ_B = 52.2 ; λ_P = 50
# w16 we2
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# b2 ; λ_B = 59.05 ; λ_P = 50
# w16 we2
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# b3 ; λ_B = 52.7 ; λ_P = 50
# w16 we2
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# b4 ; λ_B = 57.05 ; λ_P = 50
# w16 we2
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# b7 ; λ_B = 53.35 ; λ_P = 50
# w16 we2
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
# b8 ; λ_B = 56.6 ; λ_P = 50
#
# w16 we3
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# b1 ; λ_B = 51.2 ; λ_P = 48
# w16 we3
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# b2 ; λ_B = 58.05 ; λ_P = 48
# w16 we3
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# b3 ; λ_B = 51.7 ; λ_P = 48
# w16 we3
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# b4 ; λ_B = 56.05 ; λ_P = 48
# w16 we3
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# b9 ; λ_B = 52.7 ; λ_P = 48
# w16 we3
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
# b10 ; λ_B = 56.05 ; λ_P = 48
#
# w16 we4
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# b1 ; λ_B = 53.7 ; λ_P = 53
# w16 we4
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# b2 ; λ_B = 60.55 ; λ_P = 53
# w16 we4
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# b3 ; λ_B = 54.2 ; λ_P = 53
# w16 we4
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# b4 ; λ_B = 58.55 ; λ_P = 53
# w16 we4
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# b11 ; λ_B = 55.4 ; λ_P = 53
# w16 we4
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53
# b12 ; λ_B = 58.7 ; λ_P = 53

# %%
result = Dict()
println("OV = ", objective_value(co_pv))
for w in W_PP    
    println()
    print(w, ": ")
    for week in WEEK
        println()
        for b in Bt[week]
            print(b, " = ", value(PB[b,w]), " ")
        end
        for t in week_to_hour[week]
            #print("EP", " = ", value(EP[t,w]), " ")
        end
    end
end
# Out:
# OV = 7.6565476596496e6
#
# w1:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w2:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w3:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w4:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w5:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w6:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w7:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w8:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w9:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w10:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w11:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w12:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w13:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w14:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w15:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w16:
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b5 = 50.0 b6 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 0.0 b2 = 0.0 b3 = 0.0 b4 = 0.0 b11 = 0.0 b12 = 0.0

# %%
# visualization of Power purchased from bilateral contracts
x1 = Vector{Float64}()  

for b in B
    append!(x1, value.(PB[b,"w1"]))
end
PB1 = sum(value.(PB[b,"w1"]) for b in B)

x2 = Vector{Float64}()  

for b in B
    append!(x2, value.(PB[b,"w9"]))
end
PB2 = sum(value.(PB[b,"w9"]) for b in B)
display(plot(Array{Int}(1:length(x1)),x1))
display(plot(Array{Int}(1:length(x2)),x2))
println("Power purchased from bilateral contracts: ", PB1)
println("Power purchased from bilateral contracts: ", PB2)
# Out:
# Power purchased from bilateral contracts: 0.0
# Power purchased from bilateral contracts: 0.0

# %%
objective_value(co_pv)
# Out:
# 1.2977011521315321e8
