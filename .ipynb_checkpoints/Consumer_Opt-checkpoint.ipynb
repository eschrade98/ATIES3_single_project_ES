# %% [markdown]
# # Consumer Opt. with PV

# %%
using Pkg
Pkg.activate("."); 
Pkg.instantiate()
# Out:
#   Activating project at `C:\Users\ESchr\workspace\uni\ATIS3\Single_Project\ATIES3_single_project_ES`

# %%
using JuMP, LinearAlgebra, StatsPlots, Statistics, CSV, DataFrames, XLSX, CPLEX, AxisArrays, Plots

# %% [markdown]
# ## Input handling

# %%
input_path = "input\\"
#xl = XLSX.readxlsx(input_path * "input.xlsx") 
xl = XLSX.readxlsx(input_path * "input_big.xlsx") 
data = Dict()

for s in XLSX.sheetnames(xl)
    data[s] = DataFrame(XLSX.gettable(xl[s]; infer_eltypes=true)...)
end

# %%
input_path = "input\\"
xl = XLSX.readxlsx(input_path * "solar_input.xlsx") 

for s in XLSX.sheetnames(xl)
    data[s] = DataFrame(XLSX.gettable(xl[s]; infer_eltypes=true)...)
end

# %%
input_path = "input\\"
xl = XLSX.readxlsx(input_path * "prices.xlsx") 

for s in XLSX.sheetnames(xl)
    data[s] = DataFrame(XLSX.gettable(xl[s]; infer_eltypes=true)...)
end

# %%
data
# Out:
# Dict{Any, Any} with 8 entries:
#   "NU_non_anticipativity_matrix" => 15×85 DataFrame…
#   "pv_production"                => 48×85 DataFrame…
#   "prices"                       => 8761×3 DataFrame…
#   "pool_price_scenarios"         => 16×85 DataFrame…
#   "solar_input"                  => 35043×3 DataFrame…
#   "bilateral_contract_data"      => 12×9 DataFrame…
#   "non_anticipativity_matrix"    => 47×5 DataFrame…
#   "electricity_demand"           => 1×85 DataFrame…

# %% [markdown]
# # Data handling

# %%
T = data["solar_input"][:, :Time]
FC_S = data["solar_input"][:, :FC_Solar]
Act_S = data["solar_input"][:, :Act_Solar]
H = data["prices"][:, :Hour]
TIME = data["prices"][:, :Time]
DHP = data["prices"][:, :Day_Ahead_Price]
T_NQ = length(T)

valley = [1, 2, 3, 4, 5, 6, 7, 8]
shoulder = [9, 10, 11, 12, 13, 14, 15, 16]
peak = [17, 18, 19, 20, 21, 22,23, 0]

#valley = [1, 2, 3, 4, 5, 6, 7, 8]
#shoulder = [9, 10, 15, 16, 17, 18, 23, 0]
#peak = [11, 12, 13, 14, 19, 20, 21, 22]
println("Sets created")
# Out:
# Sets created

# %%
Dsolar_input = Dict(c => AxisArray(data["solar_input"][:, c], t = 1:T_NQ) for c in names(data["solar_input"]));
Dprice = Dict(c => AxisArray(data["prices"][:, c], h = H) for c in names(data["prices"]));

# %%
#combine price and solar data with hour dependcy
h = 1
i = 1
FC_Solar = 0
Act_Solar = 0
Day_Ahead_Price = 0
Data = Dict()

for t in 1:T_NQ
    FC_Solar += Dsolar_input["FC_Solar"][t]
    Act_Solar += Dsolar_input["Act_Solar"][t]
    if(h == 4)
        if(Dprice["Hour"][i] in valley)            
            PV_Data = Dict("FC_Solar" => round((FC_Solar/4), digits = 2), "Act_Solar" => round((Act_Solar/4), digits = 2), "price" => Dprice["Day_Ahead_Price"][i], "hour" => Dprice["Hour"][i], "set" => 1)
        elseif(Dprice["Hour"][i] in shoulder) 
            PV_Data = Dict("FC_Solar" => round((FC_Solar/4), digits = 2), "Act_Solar" => round((Act_Solar/4), digits = 2), "price" => Dprice["Day_Ahead_Price"][i], "hour" => Dprice["Hour"][i], "set" => 2)
        elseif(Dprice["Hour"][i] in peak) 
            PV_Data = Dict("FC_Solar" => round((FC_Solar/4), digits = 2), "Act_Solar" => round((Act_Solar/4), digits = 2), "price" => Dprice["Day_Ahead_Price"][i], "hour" => Dprice["Hour"][i], "set" => 3)
        end
        Data[i] = PV_Data
        h = 0
        i += 1
        FC_Solar = 0
        Act_Solar = 0
    end
    h += 1
end

# %%
#=
#Sets
#W_PP = data["pool_price_scenarios"][:, :Scenario]
W_NAM = data["non_anticipativity_matrix"][:, :Scenario]
B = data["bilateral_contract_data"][:, :Contract]
D = data["electricity_demand"][:, :Demand]
WEEK = ["we1", "we2", "we3", "we4"]
K = ["k1", "k2", "k3", "k4"]



#Axis arrays
#Dpool_price_scenarios = Dict(c => AxisArray(data["pool_price_scenarios"][:, c], w_pp=W_PP) for c in names(data["pool_price_scenarios"]));
Dbilateral_contract_data = Dict(c => AxisArray(data["bilateral_contract_data"][:, c], b=B) for c in names(data["bilateral_contract_data"]));
Delectricity_demand = Dict(c => AxisArray(data["electricity_demand"][:, c], d=D) for c in names(data["electricity_demand"]));
Dnon_anticipativity_matrix = Dict(c => AxisArray(data["non_anticipativity_matrix"][:, c], w_nam=W_NAM) for c in names(data["non_anticipativity_matrix"]));
Dpv_production = Dict(c => AxisArray(data["pv_production"][:, c], w_pp=W_PP) for c in names(data["pv_production"]));

#Mapping of bilateral contracts active in period T
Bt = Dict()
for week in WEEK
    temp = String[]
    for b in B
        if(Dbilateral_contract_data[week][b]==1)
            push!(temp, b)
        end
    end
    Bt[week] = temp
end 

#Mapping of decisions on bilateral contracts made in stage K
Kb = Dict()
Kb["k1"] = Bt["we1"]
Kb["k2"] = ["b7", "b8"]
Kb["k3"] = ["b9", "b10"]
Kb["k4"] = ["b12", "b11"]

#Arrays of decisions on bilateral contracts made in stage K
k1 = data["non_anticipativity_matrix"][:, :k1]
k2 = data["non_anticipativity_matrix"][:, :k2]
k3 = data["non_anticipativity_matrix"][:, :k3]
k4 = data["non_anticipativity_matrix"][:, :k4]

NW_PP = length(W_PP)

=#

# %%
Ω = String[]
for t in 1:48
    n = string("w", t)
    push!(Ω, n)
end
W_PP = Ω

T = String[]
for c in names(data["pool_price_scenarios"])
    push!(T, c)
end
T = T[2:end]

#week hour allocation 
week_to_hour = Dict()
week_to_hour["we1"] = T[1:21]
week_to_hour["we2"] = T[22:42]
week_to_hour["we3"] = T[43:63]
week_to_hour["we4"] = T[64:end]

#Arrays of decisions on bilateral contracts made in stage K
k1 = data["non_anticipativity_matrix"][:, :k1]
k2 = data["non_anticipativity_matrix"][:, :k2]
k3 = data["non_anticipativity_matrix"][:, :k3]
k4 = data["non_anticipativity_matrix"][:, :k4]
println("Sets created")
# Out:
# Sets created

# %% [markdown]
# # Scenario Generation

# %% [markdown]
# ## Spring price scenarios
# Scenarios are calculated through the different hour blocks. Therefore there exists no direct connection between two sequential hourly periods, as we consider the scenario as an average value for the hours.

# %% [markdown]
# Auf der Nordhalbkugel - also bei uns - ist am 21. März Frühlingsanfang, am 21. Juni beginnt der Sommer, am 23. September ist Herbstanfang und am 21. Dezember Winterbeginn.

# %%
#spring starts at hour 1896 and ends at 4104
D_spring_price =  Dict()
spring_price = Float64[]
spring_act_solar = Float64[]

D_spring_price1 =  Dict()
spring_price1 = Float64[]
spring_act_solar1 = Float64[]
spring_time1 = Int[]

D_spring_price2 =  Dict()
spring_price2 = Float64[]
spring_act_solar2 = Float64[]
spring_time2 = Int[]

D_spring_price3 =  Dict()
spring_price3 = Float64[]
spring_act_solar3 = Float64[]
spring_time3 = Int[]

for t in TIME[1896:4104]
    D_spring_price[t] = Data[t]
    push!(spring_price, Data[t]["price"])
    push!(spring_act_solar, Data[t]["Act_Solar"])    
    if(Data[t]["set"]==1)
        D_spring_price1[t] = Data[t]
        push!(spring_price1, Data[t]["price"])
        push!(spring_act_solar1, Data[t]["Act_Solar"])
        push!(spring_time1, t)
    elseif(Data[t]["set"]==2)
        D_spring_price2[t] = Data[t]
        push!(spring_price2, Data[t]["price"])
        push!(spring_act_solar2, Data[t]["Act_Solar"])
        push!(spring_time2, t)
    elseif(Data[t]["set"]==3)
        D_spring_price3[t] = Data[t]
        push!(spring_price3, Data[t]["price"])
        push!(spring_act_solar3, Data[t]["Act_Solar"])
        push!(spring_time3, t)
    end    
end

# %% [markdown]
# # Visualisation

# %%
path = raw"C:\Users\ ESchr\ workspace\ uni\ ATIS3\ Single_Project\ ATIES3_single_project_ES\ Plots\plot_ref"
# Out:
# "C:\\Users\\ ESchr\\ workspace\\ uni\\ ATIS3\\ Single_Project\\ ATIES3_single_project_ES\\ Plots\\plot_ref"

# %% [markdown]
# ### Spring

# %%
plot_ref = plot(spring_price3, x=:time, y=:price, label = "DA-price")
xlabel!("hour of the year 2021")
ylabel!("price DA in €")
#savefig("DA_price_yearly_h")

# %% [markdown]
# ### Spring Valley

# %%
density(spring_act_solar1, label="valley solar generation spring", color= :orange)

# %%
density(spring_price1, label="valley day-ahead prices spring")

# %% [markdown]
# ### Spring Shoulder

# %%
density(spring_act_solar2, label="shoulder solar generation spring", color= :orange)

# %%
density(spring_price2, label=" shoulder day-ahead prices spring")

# %% [markdown]
# ### Spring Peak

# %%
density(spring_act_solar3, label="peak solar generation spring", color= :orange)

# %%
density(spring_price3, label="peak day-ahead prices")

# %%
density(spring_price, label="overall day-ahead prices spring")

# %% [markdown]
# ## Scenario Creation
# Generate a tree structure with a 4×3×2×2 scenario structure, i.e., from the root node 5 branches leave, from each second-stage
# node 4 branches leave, and so on.

# %%
using StatsBase

# %%
#create scenario array
Ω = String[]
for t in 1:48
    n = string("w", t)
    push!(Ω, n)
end

#take sample from price distribution
v_s = sample(spring_time1, 616, replace = false)
s_s = sample(spring_time2, 616, replace = false)
p_s = sample(spring_time3, 616, replace = false)

v_s_price = Float64[]
for t in 1:48
    push!(v_s_price, D_spring_price[v_s[t]]["price"])
end

# %%
density(v_s_price, label="valley_sample day-ahead prices spring")
#savefig("valley_sample_DA_price_spring")

# %%
density(spring_price1, label="valley day-ahead prices spring")
#savefig("valley_DA_price_spring")

# %%
#creates scenario tree
price_scenarios_spring = DataFrame()
pv_production_scenarios_spring = DataFrame()
t_aux = 1

for k in K
    #for each stage the tree structure gets initialised
    if(k=="k1")
        s = 4
        Range = week_to_hour["we1"]
    elseif(k=="k2")
        s = 12
        Range = week_to_hour["we2"]
    elseif(k=="k3")
        s = 24
        Range = week_to_hour["we3"]
    elseif(k=="k4")
        s = 48
        Range = week_to_hour["we4"]
    end
        
    for t in Range
        p_t = Float64[]
        pv_t = Float64[]
        v_p = 0
        t_ω = 0
        temp = Dict()
        #check which period is considerd
        if(t_aux==1)
            temp = D_spring_price[pop!(v_s)]
            v_p = temp["price"]
            v_pv = temp["Act_Solar"]
        elseif(t_aux==2)
            temp = D_spring_price[pop!(s_s)]
            v_p = temp["price"]
            v_pv = temp["Act_Solar"]
        elseif(t_aux==3)
            temp = D_spring_price[pop!(p_s)]
            v_p = temp["price"]
            v_pv = temp["Act_Solar"]
        end           
        for ω in Ω            
            max_r = length(Ω)/s   
            #check on which node in tree
            if(t_ω < max_r)                
                push!(p_t, v_p)
                push!(pv_t, ((v_pv/360)*8))
            else
                #if new node is considerd
                if(t_aux==1)
                    temp = D_spring_price[pop!(v_s)]
                    v_p = temp["price"]
                    v_pv = temp["Act_Solar"]
                elseif(t_aux==2)
                    temp = D_spring_price[pop!(s_s)]
                    v_p = temp["price"]
                    v_pv = temp["Act_Solar"]
                elseif(t_aux==3)
                    temp = D_spring_price[pop!(p_s)]
                    v_p = temp["price"]
                    v_pv = temp["Act_Solar"]
                end  
                push!(p_t, v_p)
                push!(pv_t, ((v_pv/360)*8))
                t_ω = 0
            end
            t_ω += 1
        end
        if(!(t_aux==3))
            t_aux += 1
        else
            t_aux = 1
        end
        price_scenarios_spring[!, t] = p_t  
        pv_production_scenarios_spring[!, t] = pv_t
    end
end

#create AxisArrays
cols = T
Dpv_production_scenarios_spring = Dict(c => AxisArray(pv_production_scenarios_spring[:, c], w = Ω) for c in cols);
Dprice_scenarios_spring = Dict(c => AxisArray(price_scenarios_spring[:, c], w = Ω) for c in cols);

# %%
sce_price_w1 = Float64[]
sce_pv_w1 = Float64[]
for t in T
    push!(sce_pv_w1, (Dpv_production_scenarios_spring[t]["w1"]))
    push!(sce_price_w1, (Dprice_scenarios_spring[t]["w1"]))
end

# %%
plot_ref = plot(sce_price_w1, x=:time, y=:price, label = "DA-price")
xlabel!("hour of the year 2021")
ylabel!("price DA in €")
#savefig("DA_price_sc_spring")

# %%
plot_ref = plot(sce_pv_w1, x=:time, y=:price, label = "PV-production spring", color= :orange)
xlabel!("hour of the year 2021")
ylabel!("PV-production MW")
#savefig("PV_production_sc_spring")

# %%
density(sce_pv_w1, label="valley day-ahead prices spring")

# %% [markdown]
# ### Create Sets and Parameters

# %%
#Sets
#W_PP = data["pool_price_scenarios"][:, :Scenario]
W_NAM = data["non_anticipativity_matrix"][:, :Scenario]
B = data["bilateral_contract_data"][:, :Contract]
D = data["electricity_demand"][:, :Demand]
WEEK = ["we1", "we2", "we3", "we4"]
K = ["k1", "k2", "k3", "k4"]

T = String[]
for c in names(data["pool_price_scenarios"])
    push!(T, c)
end
T = T[2:end]

#Axis arrays
#Dpool_price_scenarios = Dict(c => AxisArray(data["pool_price_scenarios"][:, c], w_pp=W_PP) for c in names(data["pool_price_scenarios"]));
Dbilateral_contract_data = Dict(c => AxisArray(data["bilateral_contract_data"][:, c], b=B) for c in names(data["bilateral_contract_data"]));
Delectricity_demand = Dict(c => AxisArray(data["electricity_demand"][:, c], d=D) for c in names(data["electricity_demand"]));
Dnon_anticipativity_matrix = Dict(c => AxisArray(data["non_anticipativity_matrix"][:, c], w_nam=W_NAM) for c in names(data["non_anticipativity_matrix"]));
Dpv_production = Dict(c => AxisArray(data["pv_production"][:, c], w_pp=W_PP) for c in names(data["pv_production"]));

#Mapping of bilateral contracts active in period T
Bt = Dict()
for week in WEEK
    temp = String[]
    for b in B
        if(Dbilateral_contract_data[week][b]==1)
            push!(temp, b)
        end
    end
    Bt[week] = temp
end 

#Mapping of decisions on bilateral contracts made in stage K
Kb = Dict()
Kb["k1"] = Bt["we1"]
Kb["k2"] = ["b7", "b8"]
Kb["k3"] = ["b9", "b10"]
Kb["k4"] = ["b12", "b11"]

#Arrays of decisions on bilateral contracts made in stage K
k1 = data["non_anticipativity_matrix"][:, :k1]
k2 = data["non_anticipativity_matrix"][:, :k2]
k3 = data["non_anticipativity_matrix"][:, :k3]
k4 = data["non_anticipativity_matrix"][:, :k4]

NW_PP = length(W_PP)

#week hour allocation 
week_to_hour = Dict()
week_to_hour["we1"] = T[1:21]
week_to_hour["we2"] = T[22:42]
week_to_hour["we3"] = T[43:63]
week_to_hour["we4"] = T[64:end]
println("Sets created")
# Out:
# Sets created

# %% [markdown]
# # Model

# %%
Dpool_price_scenarios = Dprice_scenarios_spring
Dpv_production = Dpv_production_scenarios_spring
W_PP = Ω

#Probalitie for scenarios
prob = Dict()
for w in W_PP
    prob[w] = 1/length(W_PP)
end

# %%
# Risk
β = 0
α = 0.95

#Duration in hours of every period t
d = Dict()
for t in T
    d[t]=1
end

# %%
co_pv = Model(CPLEX.Optimizer)
# Out:
# A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: CPLEX

# %%
@variables(co_pv, begin
        PB[B,W_PP]            #Power purchased from bilateral contracts
        s[B,W_PP], Bin        #Selection of bilateral contracts
        EP[T,W_PP]            #Energy traded in the pool
        η[W_PP] >= 0          #Auxiliary variable used to calculate the CVaR
        ζ                     #Auxiliary variable used to calculate the CVaR
    end)
println("Variables created")

@time begin    
    λ_B = @expression(co_pv, [week in WEEK, t in week_to_hour[week], w in W_PP, b in Bt[week]], (Dpool_price_scenarios[t][w]+Dbilateral_contract_data["price"][b])/2)
    λ_P = @expression(co_pv, [t in T, w in W_PP], Dpool_price_scenarios[t][w])     
    CVaR = @expression(co_pv, β * (ζ+(1/(1-α))*sum(prob[w]*η[w] for w in W_PP)))  
    z = @expression(co_pv, sum(prob[w] * sum(sum(sum(λ_B[week, t, w, b] * PB[b,w] * d[t] for b in Bt[week]) + λ_P[t,w] * EP[t,w] for t in  week_to_hour[week]) for week in WEEK) for w in W_PP) + CVaR)
end
println("Expressions created")
# Out:
# Variables created
#   0.641376 seconds (1.26 M allocations: 67.236 MiB, 73.44% compilation time)
# Expressions created

# %%
@constraints(co_pv, begin
        LimitContractMin[b in B, w in W_PP], PB[b,w] >= s[b,w] * Dbilateral_contract_data["min_power"][b]
        LimitContractMax[b in B, w in W_PP], PB[b,w] <= s[b,w] * Dbilateral_contract_data["max_power"][b]
        
        Non_Anticipativity1[b in Kb["k1"], τ in (1:NW_PP-1)[k1.== 1]], PB[b,W_PP[τ]] == PB[b, W_PP[τ+1]]
        Non_Anticipativity2[b in Kb["k2"], τ in (1:NW_PP-1)[k2.== 1]], PB[b,W_PP[τ]] == PB[b, W_PP[τ+1]]
        Non_Anticipativity3[b in Kb["k3"], τ in (1:NW_PP-1)[k3.== 1]], PB[b,W_PP[τ]] == PB[b, W_PP[τ+1]]
        Non_Anticipativity4[b in Kb["k4"], τ in (1:NW_PP-1)[k4.== 1]], PB[b,W_PP[τ]] == PB[b, W_PP[τ+1]]
        
        Arbitrage[t in T, w in W_PP], EP[t,w] >= -Dpv_production[t][w]
        EnergyBalance[week in WEEK, t in week_to_hour[week], w in W_PP], EP[t,w] + Dpv_production[t][w] + sum(PB[b,w]*d[t] for b in Bt[week]) == Delectricity_demand[t]["d1"]
        CVaRconstr[w in W_PP], sum(sum(sum(λ_B[week, t, w, b] * PB[b,w] * d[t] for b in Bt[week]) + λ_P[t,w] * EP[t,w] for t in  week_to_hour[week]) for week in WEEK) - ζ <= η[w]
        NonNeg[w in W_PP], 0 <= η[w]        
    end)
println("Constraints created")
# Out:
# Constraints created

# %%
@time begin
    @objective(co_pv, Min, z)
end
print("Objective function created")
# Out:
#   0.000830 seconds (15 allocations: 316.406 KiB)
# Objective function created

# %%
@time begin
    optimize!(co_pv)
end
# Out:
# Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 8166 rows and 4087 columns.
# MIP Presolve modified 2 coefficients.
# Aggregator did 490 substitutions.
# Reduced MIP has 1144 rows, 656 columns, and 2288 nonzeros.
# Reduced MIP has 572 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (10.46 ticks)
# Found incumbent of value 1.0755601e+07 after 0.02 sec. (13.90 ticks)
# Probing time = 0.00 sec. (4.51 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 1143 rows and 655 columns.
# Aggregator did 1 substitutions.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.81 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (107.20 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.05 sec. (107.20 ticks)
#   0.684802 seconds (482.55 k allocations: 24.358 MiB)

# %% [markdown]
# # Results

# %%
for w in W_PP    
    PB_w = sum(value.(PB[b,w]) for b in B)
    println(w, " = ", PB2)
end
# Out:
# w1 = 200.0
# w2 = 200.0
# w3 = 200.0
# w4 = 200.0
# w5 = 200.0
# w6 = 200.0
# w7 = 200.0
# w8 = 200.0
# w9 = 200.0
# w10 = 200.0
# w11 = 200.0
# w12 = 200.0
# w13 = 200.0
# w14 = 200.0
# w15 = 200.0
# w16 = 200.0
# w17 = 200.0
# w18 = 200.0
# w19 = 200.0
# w20 = 200.0
# w21 = 200.0
# w22 = 200.0
# w23 = 200.0
# w24 = 200.0
# w25 = 200.0
# w26 = 200.0
# w27 = 200.0
# w28 = 200.0
# w29 = 200.0
# w30 = 200.0
# w31 = 200.0
# w32 = 200.0
# w33 = 200.0
# w34 = 200.0
# w35 = 200.0
# w36 = 200.0
# w37 = 200.0
# w38 = 200.0
# w39 = 200.0
# w40 = 200.0
# w41 = 200.0
# w42 = 200.0
# w43 = 200.0
# w44 = 200.0
# w45 = 200.0
# w46 = 200.0
# w47 = 200.0
# w48 = 200.0

# %%
# visualization of Power purchased from bilateral contracts
x1 = Vector{Float64}()  
for t in T
    append!(x1, value.(λ_P[t,"w1"]))
end
PB1 = sum(value.(λ_P[t,"w1"]) for t in T)

x2 = Vector{Float64}()  
for t in T
    append!(x2, value.(λ_P[t,"w16"]))
end
PB2 = sum(value.(λ_P[t,"w16"]) for t in T)

display(plot(Array{Int}(1:length(x1)),x1, label="pool price w1"))
display(plot(Array{Int}(1:length(x2)),x2, label="pool price w10"))
println("Price in w1: ", PB1)
println("Price in w16: ", PB2)
# Out:
# Price in w1: 4843.4400000000005
# Price in w16: 4921.92

# %%
#prices per scenario
for w in W_PP    
    for week in WEEK        
        for b in Bt[week]
            println(w," ", week)
        for t in week_to_hour[week]
            print(b," ; λ_B = ", value(λ_B[week, t, w, b]))
            println(" ; λ_P = ", value(λ_P[t,w]))
        end
        end
        println()
    end
end
# Out:
# w1 we1
# b1 ; λ_B = 72.235 ; λ_P = 90.07
# b1 ; λ_B = 46.565 ; λ_P = 38.73
# b1 ; λ_B = 69.22 ; λ_P = 84.04
# b1 ; λ_B = 45.2 ; λ_P = 36.0
# b1 ; λ_B = 50.41 ; λ_P = 46.42
# b1 ; λ_B = 64.685 ; λ_P = 74.97
# b1 ; λ_B = 52.58 ; λ_P = 50.76
# b1 ; λ_B = 34.705 ; λ_P = 15.01
# b1 ; λ_B = 71.7 ; λ_P = 89.0
# b1 ; λ_B = 51.08 ; λ_P = 47.76
# b1 ; λ_B = 56.53 ; λ_P = 58.66
# b1 ; λ_B = 57.54 ; λ_P = 60.68
# b1 ; λ_B = 62.745000000000005 ; λ_P = 71.09
# b1 ; λ_B = 58.724999999999994 ; λ_P = 63.05
# b1 ; λ_B = 77.62 ; λ_P = 100.84
# b1 ; λ_B = 48.205 ; λ_P = 42.01
# b1 ; λ_B = 57.16 ; λ_P = 59.92
# b1 ; λ_B = 60.565 ; λ_P = 66.73
# b1 ; λ_B = 53.45 ; λ_P = 52.5
# b1 ; λ_B = 60.19 ; λ_P = 65.98
# b1 ; λ_B = 51.849999999999994 ; λ_P = 49.3
# w1 we1
# b2 ; λ_B = 79.085 ; λ_P = 90.07
# b2 ; λ_B = 53.41499999999999 ; λ_P = 38.73
# b2 ; λ_B = 76.07 ; λ_P = 84.04
# b2 ; λ_B = 52.05 ; λ_P = 36.0
# b2 ; λ_B = 57.26 ; λ_P = 46.42
# b2 ; λ_B = 71.535 ; λ_P = 74.97
# b2 ; λ_B = 59.42999999999999 ; λ_P = 50.76
# b2 ; λ_B = 41.555 ; λ_P = 15.01
# b2 ; λ_B = 78.55 ; λ_P = 89.0
# b2 ; λ_B = 57.92999999999999 ; λ_P = 47.76
# b2 ; λ_B = 63.379999999999995 ; λ_P = 58.66
# b2 ; λ_B = 64.39 ; λ_P = 60.68
# b2 ; λ_B = 69.595 ; λ_P = 71.09
# b2 ; λ_B = 65.57499999999999 ; λ_P = 63.05
# b2 ; λ_B = 84.47 ; λ_P = 100.84
# b2 ; λ_B = 55.05499999999999 ; λ_P = 42.01
# b2 ; λ_B = 64.00999999999999 ; λ_P = 59.92
# b2 ; λ_B = 67.41499999999999 ; λ_P = 66.73
# b2 ; λ_B = 60.3 ; λ_P = 52.5
# b2 ; λ_B = 67.03999999999999 ; λ_P = 65.98
# b2 ; λ_B = 58.699999999999996 ; λ_P = 49.3
# w1 we1
# b3 ; λ_B = 72.735 ; λ_P = 90.07
# b3 ; λ_B = 47.065 ; λ_P = 38.73
# b3 ; λ_B = 69.72 ; λ_P = 84.04
# b3 ; λ_B = 45.7 ; λ_P = 36.0
# b3 ; λ_B = 50.91 ; λ_P = 46.42
# b3 ; λ_B = 65.185 ; λ_P = 74.97
# b3 ; λ_B = 53.08 ; λ_P = 50.76
# b3 ; λ_B = 35.205 ; λ_P = 15.01
# b3 ; λ_B = 72.2 ; λ_P = 89.0
# b3 ; λ_B = 51.58 ; λ_P = 47.76
# b3 ; λ_B = 57.03 ; λ_P = 58.66
# b3 ; λ_B = 58.04 ; λ_P = 60.68
# b3 ; λ_B = 63.245000000000005 ; λ_P = 71.09
# b3 ; λ_B = 59.224999999999994 ; λ_P = 63.05
# b3 ; λ_B = 78.12 ; λ_P = 100.84
# b3 ; λ_B = 48.705 ; λ_P = 42.01
# b3 ; λ_B = 57.66 ; λ_P = 59.92
# b3 ; λ_B = 61.065 ; λ_P = 66.73
# b3 ; λ_B = 53.95 ; λ_P = 52.5
# b3 ; λ_B = 60.69 ; λ_P = 65.98
# b3 ; λ_B = 52.349999999999994 ; λ_P = 49.3
# w1 we1
# b4 ; λ_B = 77.085 ; λ_P = 90.07
# b4 ; λ_B = 51.41499999999999 ; λ_P = 38.73
# b4 ; λ_B = 74.07 ; λ_P = 84.04
# b4 ; λ_B = 50.05 ; λ_P = 36.0
# b4 ; λ_B = 55.26 ; λ_P = 46.42
# b4 ; λ_B = 69.535 ; λ_P = 74.97
# b4 ; λ_B = 57.42999999999999 ; λ_P = 50.76
# b4 ; λ_B = 39.555 ; λ_P = 15.01
# b4 ; λ_B = 76.55 ; λ_P = 89.0
# b4 ; λ_B = 55.92999999999999 ; λ_P = 47.76
# b4 ; λ_B = 61.379999999999995 ; λ_P = 58.66
# b4 ; λ_B = 62.39 ; λ_P = 60.68
# b4 ; λ_B = 67.595 ; λ_P = 71.09
# b4 ; λ_B = 63.574999999999996 ; λ_P = 63.05
# b4 ; λ_B = 82.47 ; λ_P = 100.84
# b4 ; λ_B = 53.05499999999999 ; λ_P = 42.01
# b4 ; λ_B = 62.01 ; λ_P = 59.92
# b4 ; λ_B = 65.41499999999999 ; λ_P = 66.73
# b4 ; λ_B = 58.3 ; λ_P = 52.5
# b4 ; λ_B = 65.03999999999999 ; λ_P = 65.98
# b4 ; λ_B = 56.699999999999996 ; λ_P = 49.3
# w1 we1
# b5 ; λ_B = 67.985 ; λ_P = 90.07
# b5 ; λ_B = 42.315 ; λ_P = 38.73
# b5 ; λ_B = 64.97 ; λ_P = 84.04
# b5 ; λ_B = 40.95 ; λ_P = 36.0
# b5 ; λ_B = 46.16 ; λ_P = 46.42
# b5 ; λ_B = 60.435 ; λ_P = 74.97
# b5 ; λ_B = 48.33 ; λ_P = 50.76
# b5 ; λ_B = 30.455 ; λ_P = 15.01
# b5 ; λ_B = 67.45 ; λ_P = 89.0
# b5 ; λ_B = 46.83 ; λ_P = 47.76
# b5 ; λ_B = 52.28 ; λ_P = 58.66
# b5 ; λ_B = 53.29 ; λ_P = 60.68
# b5 ; λ_B = 58.495000000000005 ; λ_P = 71.09
# b5 ; λ_B = 54.474999999999994 ; λ_P = 63.05
# b5 ; λ_B = 73.37 ; λ_P = 100.84
# b5 ; λ_B = 43.955 ; λ_P = 42.01
# b5 ; λ_B = 52.91 ; λ_P = 59.92
# b5 ; λ_B = 56.315 ; λ_P = 66.73
# b5 ; λ_B = 49.2 ; λ_P = 52.5
# b5 ; λ_B = 55.94 ; λ_P = 65.98
# b5 ; λ_B = 47.599999999999994 ; λ_P = 49.3
# w1 we1
# b6 ; λ_B = 73.035 ; λ_P = 90.07
# b6 ; λ_B = 47.364999999999995 ; λ_P = 38.73
# b6 ; λ_B = 70.02000000000001 ; λ_P = 84.04
# b6 ; λ_B = 46.0 ; λ_P = 36.0
# b6 ; λ_B = 51.21 ; λ_P = 46.42
# b6 ; λ_B = 65.485 ; λ_P = 74.97
# b6 ; λ_B = 53.379999999999995 ; λ_P = 50.76
# b6 ; λ_B = 35.505 ; λ_P = 15.01
# b6 ; λ_B = 72.5 ; λ_P = 89.0
# b6 ; λ_B = 51.879999999999995 ; λ_P = 47.76
# b6 ; λ_B = 57.33 ; λ_P = 58.66
# b6 ; λ_B = 58.34 ; λ_P = 60.68
# b6 ; λ_B = 63.545 ; λ_P = 71.09
# b6 ; λ_B = 59.525 ; λ_P = 63.05
# b6 ; λ_B = 78.42 ; λ_P = 100.84
# b6 ; λ_B = 49.004999999999995 ; λ_P = 42.01
# b6 ; λ_B = 57.96 ; λ_P = 59.92
# b6 ; λ_B = 61.365 ; λ_P = 66.73
# b6 ; λ_B = 54.25 ; λ_P = 52.5
# b6 ; λ_B = 60.99 ; λ_P = 65.98
# b6 ; λ_B = 52.65 ; λ_P = 49.3
#
# w1 we2
# b1 ; λ_B = 68.27 ; λ_P = 82.14
# b1 ; λ_B = 48.01 ; λ_P = 41.62
# b1 ; λ_B = 47.675 ; λ_P = 40.95
# b1 ; λ_B = 55.56 ; λ_P = 56.72
# b1 ; λ_B = 56.39 ; λ_P = 58.38
# b1 ; λ_B = 60.045 ; λ_P = 65.69
# b1 ; λ_B = 56.67 ; λ_P = 58.94
# b1 ; λ_B = -6.800000000000001 ; λ_P = -68.0
# b1 ; λ_B = 54.655 ; λ_P = 54.91
# b1 ; λ_B = 62.235 ; λ_P = 70.07
# b1 ; λ_B = 59.135 ; λ_P = 63.87
# b1 ; λ_B = 69.41 ; λ_P = 84.42
# b1 ; λ_B = 69.065 ; λ_P = 83.73
# b1 ; λ_B = 59.2 ; λ_P = 64.0
# b1 ; λ_B = 54.995000000000005 ; λ_P = 55.59
# b1 ; λ_B = 38.26 ; λ_P = 22.12
# b1 ; λ_B = 53.565 ; λ_P = 52.73
# b1 ; λ_B = 66.865 ; λ_P = 79.33
# b1 ; λ_B = 65.7 ; λ_P = 77.0
# b1 ; λ_B = 51.91 ; λ_P = 49.42
# b1 ; λ_B = 58.33 ; λ_P = 62.26
# w1 we2
# b2 ; λ_B = 75.12 ; λ_P = 82.14
# b2 ; λ_B = 54.86 ; λ_P = 41.62
# b2 ; λ_B = 54.525 ; λ_P = 40.95
# b2 ; λ_B = 62.41 ; λ_P = 56.72
# b2 ; λ_B = 63.239999999999995 ; λ_P = 58.38
# b2 ; λ_B = 66.895 ; λ_P = 65.69
# b2 ; λ_B = 63.519999999999996 ; λ_P = 58.94
# b2 ; λ_B = 0.04999999999999716 ; λ_P = -68.0
# b2 ; λ_B = 61.504999999999995 ; λ_P = 54.91
# b2 ; λ_B = 69.085 ; λ_P = 70.07
# b2 ; λ_B = 65.985 ; λ_P = 63.87
# b2 ; λ_B = 76.25999999999999 ; λ_P = 84.42
# b2 ; λ_B = 75.91499999999999 ; λ_P = 83.73
# b2 ; λ_B = 66.05 ; λ_P = 64.0
# b2 ; λ_B = 61.845 ; λ_P = 55.59
# b2 ; λ_B = 45.11 ; λ_P = 22.12
# b2 ; λ_B = 60.41499999999999 ; λ_P = 52.73
# b2 ; λ_B = 73.715 ; λ_P = 79.33
# b2 ; λ_B = 72.55 ; λ_P = 77.0
# b2 ; λ_B = 58.76 ; λ_P = 49.42
# b2 ; λ_B = 65.17999999999999 ; λ_P = 62.26
# w1 we2
# b3 ; λ_B = 68.77 ; λ_P = 82.14
# b3 ; λ_B = 48.51 ; λ_P = 41.62
# b3 ; λ_B = 48.175 ; λ_P = 40.95
# b3 ; λ_B = 56.06 ; λ_P = 56.72
# b3 ; λ_B = 56.89 ; λ_P = 58.38
# b3 ; λ_B = 60.545 ; λ_P = 65.69
# b3 ; λ_B = 57.17 ; λ_P = 58.94
# b3 ; λ_B = -6.300000000000001 ; λ_P = -68.0
# b3 ; λ_B = 55.155 ; λ_P = 54.91
# b3 ; λ_B = 62.735 ; λ_P = 70.07
# b3 ; λ_B = 59.635 ; λ_P = 63.87
# b3 ; λ_B = 69.91 ; λ_P = 84.42
# b3 ; λ_B = 69.565 ; λ_P = 83.73
# b3 ; λ_B = 59.7 ; λ_P = 64.0
# b3 ; λ_B = 55.495000000000005 ; λ_P = 55.59
# b3 ; λ_B = 38.76 ; λ_P = 22.12
# b3 ; λ_B = 54.065 ; λ_P = 52.73
# b3 ; λ_B = 67.365 ; λ_P = 79.33
# b3 ; λ_B = 66.2 ; λ_P = 77.0
# b3 ; λ_B = 52.41 ; λ_P = 49.42
# b3 ; λ_B = 58.83 ; λ_P = 62.26
# w1 we2
# b4 ; λ_B = 73.12 ; λ_P = 82.14
# b4 ; λ_B = 52.86 ; λ_P = 41.62
# b4 ; λ_B = 52.525 ; λ_P = 40.95
# b4 ; λ_B = 60.41 ; λ_P = 56.72
# b4 ; λ_B = 61.239999999999995 ; λ_P = 58.38
# b4 ; λ_B = 64.895 ; λ_P = 65.69
# b4 ; λ_B = 61.519999999999996 ; λ_P = 58.94
# b4 ; λ_B = -1.9500000000000028 ; λ_P = -68.0
# b4 ; λ_B = 59.504999999999995 ; λ_P = 54.91
# b4 ; λ_B = 67.085 ; λ_P = 70.07
# b4 ; λ_B = 63.985 ; λ_P = 63.87
# b4 ; λ_B = 74.25999999999999 ; λ_P = 84.42
# b4 ; λ_B = 73.91499999999999 ; λ_P = 83.73
# b4 ; λ_B = 64.05 ; λ_P = 64.0
# b4 ; λ_B = 59.845 ; λ_P = 55.59
# b4 ; λ_B = 43.11 ; λ_P = 22.12
# b4 ; λ_B = 58.41499999999999 ; λ_P = 52.73
# b4 ; λ_B = 71.715 ; λ_P = 79.33
# b4 ; λ_B = 70.55 ; λ_P = 77.0
# b4 ; λ_B = 56.76 ; λ_P = 49.42
# b4 ; λ_B = 63.17999999999999 ; λ_P = 62.26
# w1 we2
# b7 ; λ_B = 69.42 ; λ_P = 82.14
# b7 ; λ_B = 49.16 ; λ_P = 41.62
# b7 ; λ_B = 48.825 ; λ_P = 40.95
# b7 ; λ_B = 56.71 ; λ_P = 56.72
# b7 ; λ_B = 57.540000000000006 ; λ_P = 58.38
# b7 ; λ_B = 61.195 ; λ_P = 65.69
# b7 ; λ_B = 57.82 ; λ_P = 58.94
# b7 ; λ_B = -5.649999999999999 ; λ_P = -68.0
# b7 ; λ_B = 55.805 ; λ_P = 54.91
# b7 ; λ_B = 63.385 ; λ_P = 70.07
# b7 ; λ_B = 60.285 ; λ_P = 63.87
# b7 ; λ_B = 70.56 ; λ_P = 84.42
# b7 ; λ_B = 70.215 ; λ_P = 83.73
# b7 ; λ_B = 60.35 ; λ_P = 64.0
# b7 ; λ_B = 56.145 ; λ_P = 55.59
# b7 ; λ_B = 39.410000000000004 ; λ_P = 22.12
# b7 ; λ_B = 54.715 ; λ_P = 52.73
# b7 ; λ_B = 68.015 ; λ_P = 79.33
# b7 ; λ_B = 66.85 ; λ_P = 77.0
# b7 ; λ_B = 53.06 ; λ_P = 49.42
# b7 ; λ_B = 59.480000000000004 ; λ_P = 62.26
# w1 we2
# b8 ; λ_B = 72.67 ; λ_P = 82.14
# b8 ; λ_B = 52.41 ; λ_P = 41.62
# b8 ; λ_B = 52.075 ; λ_P = 40.95
# b8 ; λ_B = 59.96 ; λ_P = 56.72
# b8 ; λ_B = 60.790000000000006 ; λ_P = 58.38
# b8 ; λ_B = 64.445 ; λ_P = 65.69
# b8 ; λ_B = 61.07 ; λ_P = 58.94
# b8 ; λ_B = -2.3999999999999986 ; λ_P = -68.0
# b8 ; λ_B = 59.055 ; λ_P = 54.91
# b8 ; λ_B = 66.63499999999999 ; λ_P = 70.07
# b8 ; λ_B = 63.535 ; λ_P = 63.87
# b8 ; λ_B = 73.81 ; λ_P = 84.42
# b8 ; λ_B = 73.465 ; λ_P = 83.73
# b8 ; λ_B = 63.6 ; λ_P = 64.0
# b8 ; λ_B = 59.395 ; λ_P = 55.59
# b8 ; λ_B = 42.660000000000004 ; λ_P = 22.12
# b8 ; λ_B = 57.965 ; λ_P = 52.73
# b8 ; λ_B = 71.265 ; λ_P = 79.33
# b8 ; λ_B = 70.1 ; λ_P = 77.0
# b8 ; λ_B = 56.31 ; λ_P = 49.42
# b8 ; λ_B = 62.730000000000004 ; λ_P = 62.26
#
# w1 we3
# b1 ; λ_B = 55.76 ; λ_P = 57.12
# b1 ; λ_B = 20.145 ; λ_P = -14.11
# b1 ; λ_B = 72.265 ; λ_P = 90.13
# b1 ; λ_B = 52.224999999999994 ; λ_P = 50.05
# b1 ; λ_B = 51.769999999999996 ; λ_P = 49.14
# b1 ; λ_B = 58.65 ; λ_P = 62.9
# b1 ; λ_B = 49.545 ; λ_P = 44.69
# b1 ; λ_B = 61.19 ; λ_P = 67.98
# b1 ; λ_B = 61.2 ; λ_P = 68.0
# b1 ; λ_B = 71.835 ; λ_P = 89.27
# b1 ; λ_B = 41.68 ; λ_P = 28.96
# b1 ; λ_B = 64.42 ; λ_P = 74.44
# b1 ; λ_B = 70.17 ; λ_P = 85.94
# b1 ; λ_B = 36.945 ; λ_P = 19.49
# b1 ; λ_B = 70.55 ; λ_P = 86.7
# b1 ; λ_B = 50.905 ; λ_P = 47.41
# b1 ; λ_B = 67.9 ; λ_P = 81.4
# b1 ; λ_B = 67.7 ; λ_P = 81.0
# b1 ; λ_B = 68.98 ; λ_P = 83.56
# b1 ; λ_B = 52.19 ; λ_P = 49.98
# b1 ; λ_B = 64.7 ; λ_P = 75.0
# w1 we3
# b2 ; λ_B = 62.61 ; λ_P = 57.12
# b2 ; λ_B = 26.994999999999997 ; λ_P = -14.11
# b2 ; λ_B = 79.115 ; λ_P = 90.13
# b2 ; λ_B = 59.074999999999996 ; λ_P = 50.05
# b2 ; λ_B = 58.62 ; λ_P = 49.14
# b2 ; λ_B = 65.5 ; λ_P = 62.9
# b2 ; λ_B = 56.394999999999996 ; λ_P = 44.69
# b2 ; λ_B = 68.03999999999999 ; λ_P = 67.98
# b2 ; λ_B = 68.05 ; λ_P = 68.0
# b2 ; λ_B = 78.685 ; λ_P = 89.27
# b2 ; λ_B = 48.53 ; λ_P = 28.96
# b2 ; λ_B = 71.27 ; λ_P = 74.44
# b2 ; λ_B = 77.02 ; λ_P = 85.94
# b2 ; λ_B = 43.794999999999995 ; λ_P = 19.49
# b2 ; λ_B = 77.4 ; λ_P = 86.7
# b2 ; λ_B = 57.754999999999995 ; λ_P = 47.41
# b2 ; λ_B = 74.75 ; λ_P = 81.4
# b2 ; λ_B = 74.55 ; λ_P = 81.0
# b2 ; λ_B = 75.83 ; λ_P = 83.56
# b2 ; λ_B = 59.03999999999999 ; λ_P = 49.98
# b2 ; λ_B = 71.55 ; λ_P = 75.0
# w1 we3
# b3 ; λ_B = 56.26 ; λ_P = 57.12
# b3 ; λ_B = 20.645 ; λ_P = -14.11
# b3 ; λ_B = 72.765 ; λ_P = 90.13
# b3 ; λ_B = 52.724999999999994 ; λ_P = 50.05
# b3 ; λ_B = 52.269999999999996 ; λ_P = 49.14
# b3 ; λ_B = 59.15 ; λ_P = 62.9
# b3 ; λ_B = 50.045 ; λ_P = 44.69
# b3 ; λ_B = 61.69 ; λ_P = 67.98
# b3 ; λ_B = 61.7 ; λ_P = 68.0
# b3 ; λ_B = 72.335 ; λ_P = 89.27
# b3 ; λ_B = 42.18 ; λ_P = 28.96
# b3 ; λ_B = 64.92 ; λ_P = 74.44
# b3 ; λ_B = 70.67 ; λ_P = 85.94
# b3 ; λ_B = 37.445 ; λ_P = 19.49
# b3 ; λ_B = 71.05 ; λ_P = 86.7
# b3 ; λ_B = 51.405 ; λ_P = 47.41
# b3 ; λ_B = 68.4 ; λ_P = 81.4
# b3 ; λ_B = 68.2 ; λ_P = 81.0
# b3 ; λ_B = 69.48 ; λ_P = 83.56
# b3 ; λ_B = 52.69 ; λ_P = 49.98
# b3 ; λ_B = 65.2 ; λ_P = 75.0
# w1 we3
# b4 ; λ_B = 60.61 ; λ_P = 57.12
# b4 ; λ_B = 24.994999999999997 ; λ_P = -14.11
# b4 ; λ_B = 77.115 ; λ_P = 90.13
# b4 ; λ_B = 57.074999999999996 ; λ_P = 50.05
# b4 ; λ_B = 56.62 ; λ_P = 49.14
# b4 ; λ_B = 63.5 ; λ_P = 62.9
# b4 ; λ_B = 54.394999999999996 ; λ_P = 44.69
# b4 ; λ_B = 66.03999999999999 ; λ_P = 67.98
# b4 ; λ_B = 66.05 ; λ_P = 68.0
# b4 ; λ_B = 76.685 ; λ_P = 89.27
# b4 ; λ_B = 46.53 ; λ_P = 28.96
# b4 ; λ_B = 69.27 ; λ_P = 74.44
# b4 ; λ_B = 75.02 ; λ_P = 85.94
# b4 ; λ_B = 41.794999999999995 ; λ_P = 19.49
# b4 ; λ_B = 75.4 ; λ_P = 86.7
# b4 ; λ_B = 55.754999999999995 ; λ_P = 47.41
# b4 ; λ_B = 72.75 ; λ_P = 81.4
# b4 ; λ_B = 72.55 ; λ_P = 81.0
# b4 ; λ_B = 73.83 ; λ_P = 83.56
# b4 ; λ_B = 57.03999999999999 ; λ_P = 49.98
# b4 ; λ_B = 69.55 ; λ_P = 75.0
# w1 we3
# b9 ; λ_B = 57.26 ; λ_P = 57.12
# b9 ; λ_B = 21.645 ; λ_P = -14.11
# b9 ; λ_B = 73.765 ; λ_P = 90.13
# b9 ; λ_B = 53.724999999999994 ; λ_P = 50.05
# b9 ; λ_B = 53.269999999999996 ; λ_P = 49.14
# b9 ; λ_B = 60.15 ; λ_P = 62.9
# b9 ; λ_B = 51.045 ; λ_P = 44.69
# b9 ; λ_B = 62.69 ; λ_P = 67.98
# b9 ; λ_B = 62.7 ; λ_P = 68.0
# b9 ; λ_B = 73.335 ; λ_P = 89.27
# b9 ; λ_B = 43.18 ; λ_P = 28.96
# b9 ; λ_B = 65.92 ; λ_P = 74.44
# b9 ; λ_B = 71.67 ; λ_P = 85.94
# b9 ; λ_B = 38.445 ; λ_P = 19.49
# b9 ; λ_B = 72.05 ; λ_P = 86.7
# b9 ; λ_B = 52.405 ; λ_P = 47.41
# b9 ; λ_B = 69.4 ; λ_P = 81.4
# b9 ; λ_B = 69.2 ; λ_P = 81.0
# b9 ; λ_B = 70.48 ; λ_P = 83.56
# b9 ; λ_B = 53.69 ; λ_P = 49.98
# b9 ; λ_B = 66.2 ; λ_P = 75.0
# w1 we3
# b10 ; λ_B = 60.61 ; λ_P = 57.12
# b10 ; λ_B = 24.994999999999997 ; λ_P = -14.11
# b10 ; λ_B = 77.115 ; λ_P = 90.13
# b10 ; λ_B = 57.074999999999996 ; λ_P = 50.05
# b10 ; λ_B = 56.62 ; λ_P = 49.14
# b10 ; λ_B = 63.5 ; λ_P = 62.9
# b10 ; λ_B = 54.394999999999996 ; λ_P = 44.69
# b10 ; λ_B = 66.03999999999999 ; λ_P = 67.98
# b10 ; λ_B = 66.05 ; λ_P = 68.0
# b10 ; λ_B = 76.685 ; λ_P = 89.27
# b10 ; λ_B = 46.53 ; λ_P = 28.96
# b10 ; λ_B = 69.27 ; λ_P = 74.44
# b10 ; λ_B = 75.02 ; λ_P = 85.94
# b10 ; λ_B = 41.794999999999995 ; λ_P = 19.49
# b10 ; λ_B = 75.4 ; λ_P = 86.7
# b10 ; λ_B = 55.754999999999995 ; λ_P = 47.41
# b10 ; λ_B = 72.75 ; λ_P = 81.4
# b10 ; λ_B = 72.55 ; λ_P = 81.0
# b10 ; λ_B = 73.83 ; λ_P = 83.56
# b10 ; λ_B = 57.03999999999999 ; λ_P = 49.98
# b10 ; λ_B = 69.55 ; λ_P = 75.0
#
# w1 we4
# b1 ; λ_B = 60.22 ; λ_P = 66.04
# b1 ; λ_B = 65.69 ; λ_P = 76.98
# b1 ; λ_B = 57.989999999999995 ; λ_P = 61.58
# b1 ; λ_B = 30.875 ; λ_P = 7.35
# b1 ; λ_B = 47.989999999999995 ; λ_P = 41.58
# b1 ; λ_B = 55.295 ; λ_P = 56.19
# b1 ; λ_B = 54.125 ; λ_P = 53.85
# b1 ; λ_B = 57.21 ; λ_P = 60.02
# b1 ; λ_B = 68.175 ; λ_P = 81.95
# b1 ; λ_B = 42.445 ; λ_P = 30.49
# b1 ; λ_B = 59.67999999999999 ; λ_P = 64.96
# b1 ; λ_B = 53.55 ; λ_P = 52.7
# b1 ; λ_B = 54.980000000000004 ; λ_P = 55.56
# b1 ; λ_B = 56.465 ; λ_P = 58.53
# b1 ; λ_B = 53.864999999999995 ; λ_P = 53.33
# b1 ; λ_B = 51.5 ; λ_P = 48.6
# b1 ; λ_B = 57.2 ; λ_P = 60.0
# b1 ; λ_B = 62.230000000000004 ; λ_P = 70.06
# b1 ; λ_B = 54.644999999999996 ; λ_P = 54.89
# b1 ; λ_B = 47.114999999999995 ; λ_P = 39.83
# b1 ; λ_B = 52.445 ; λ_P = 50.49
# w1 we4
# b2 ; λ_B = 67.07 ; λ_P = 66.04
# b2 ; λ_B = 72.53999999999999 ; λ_P = 76.98
# b2 ; λ_B = 64.84 ; λ_P = 61.58
# b2 ; λ_B = 37.724999999999994 ; λ_P = 7.35
# b2 ; λ_B = 54.839999999999996 ; λ_P = 41.58
# b2 ; λ_B = 62.144999999999996 ; λ_P = 56.19
# b2 ; λ_B = 60.974999999999994 ; λ_P = 53.85
# b2 ; λ_B = 64.06 ; λ_P = 60.02
# b2 ; λ_B = 75.025 ; λ_P = 81.95
# b2 ; λ_B = 49.294999999999995 ; λ_P = 30.49
# b2 ; λ_B = 66.53 ; λ_P = 64.96
# b2 ; λ_B = 60.4 ; λ_P = 52.7
# b2 ; λ_B = 61.83 ; λ_P = 55.56
# b2 ; λ_B = 63.315 ; λ_P = 58.53
# b2 ; λ_B = 60.714999999999996 ; λ_P = 53.33
# b2 ; λ_B = 58.349999999999994 ; λ_P = 48.6
# b2 ; λ_B = 64.05 ; λ_P = 60.0
# b2 ; λ_B = 69.08 ; λ_P = 70.06
# b2 ; λ_B = 61.495 ; λ_P = 54.89
# b2 ; λ_B = 53.964999999999996 ; λ_P = 39.83
# b2 ; λ_B = 59.295 ; λ_P = 50.49
# w1 we4
# b3 ; λ_B = 60.72 ; λ_P = 66.04
# b3 ; λ_B = 66.19 ; λ_P = 76.98
# b3 ; λ_B = 58.489999999999995 ; λ_P = 61.58
# b3 ; λ_B = 31.375 ; λ_P = 7.35
# b3 ; λ_B = 48.489999999999995 ; λ_P = 41.58
# b3 ; λ_B = 55.795 ; λ_P = 56.19
# b3 ; λ_B = 54.625 ; λ_P = 53.85
# b3 ; λ_B = 57.71 ; λ_P = 60.02
# b3 ; λ_B = 68.675 ; λ_P = 81.95
# b3 ; λ_B = 42.945 ; λ_P = 30.49
# b3 ; λ_B = 60.17999999999999 ; λ_P = 64.96
# b3 ; λ_B = 54.05 ; λ_P = 52.7
# b3 ; λ_B = 55.480000000000004 ; λ_P = 55.56
# b3 ; λ_B = 56.965 ; λ_P = 58.53
# b3 ; λ_B = 54.364999999999995 ; λ_P = 53.33
# b3 ; λ_B = 52.0 ; λ_P = 48.6
# b3 ; λ_B = 57.7 ; λ_P = 60.0
# b3 ; λ_B = 62.730000000000004 ; λ_P = 70.06
# b3 ; λ_B = 55.144999999999996 ; λ_P = 54.89
# b3 ; λ_B = 47.614999999999995 ; λ_P = 39.83
# b3 ; λ_B = 52.945 ; λ_P = 50.49
# w1 we4
# b4 ; λ_B = 65.07 ; λ_P = 66.04
# b4 ; λ_B = 70.53999999999999 ; λ_P = 76.98
# b4 ; λ_B = 62.839999999999996 ; λ_P = 61.58
# b4 ; λ_B = 35.724999999999994 ; λ_P = 7.35
# b4 ; λ_B = 52.839999999999996 ; λ_P = 41.58
# b4 ; λ_B = 60.144999999999996 ; λ_P = 56.19
# b4 ; λ_B = 58.974999999999994 ; λ_P = 53.85
# b4 ; λ_B = 62.06 ; λ_P = 60.02
# b4 ; λ_B = 73.025 ; λ_P = 81.95
# b4 ; λ_B = 47.294999999999995 ; λ_P = 30.49
# b4 ; λ_B = 64.53 ; λ_P = 64.96
# b4 ; λ_B = 58.4 ; λ_P = 52.7
# b4 ; λ_B = 59.83 ; λ_P = 55.56
# b4 ; λ_B = 61.315 ; λ_P = 58.53
# b4 ; λ_B = 58.714999999999996 ; λ_P = 53.33
# b4 ; λ_B = 56.349999999999994 ; λ_P = 48.6
# b4 ; λ_B = 62.05 ; λ_P = 60.0
# b4 ; λ_B = 67.08 ; λ_P = 70.06
# b4 ; λ_B = 59.495 ; λ_P = 54.89
# b4 ; λ_B = 51.964999999999996 ; λ_P = 39.83
# b4 ; λ_B = 57.295 ; λ_P = 50.49
# w1 we4
# b11 ; λ_B = 61.92 ; λ_P = 66.04
# b11 ; λ_B = 67.39 ; λ_P = 76.98
# b11 ; λ_B = 59.69 ; λ_P = 61.58
# b11 ; λ_B = 32.574999999999996 ; λ_P = 7.35
# b11 ; λ_B = 49.69 ; λ_P = 41.58
# b11 ; λ_B = 56.995 ; λ_P = 56.19
# b11 ; λ_B = 55.825 ; λ_P = 53.85
# b11 ; λ_B = 58.91 ; λ_P = 60.02
# b11 ; λ_B = 69.875 ; λ_P = 81.95
# b11 ; λ_B = 44.144999999999996 ; λ_P = 30.49
# b11 ; λ_B = 61.379999999999995 ; λ_P = 64.96
# b11 ; λ_B = 55.25 ; λ_P = 52.7
# b11 ; λ_B = 56.68 ; λ_P = 55.56
# b11 ; λ_B = 58.165 ; λ_P = 58.53
# b11 ; λ_B = 55.565 ; λ_P = 53.33
# b11 ; λ_B = 53.2 ; λ_P = 48.6
# b11 ; λ_B = 58.9 ; λ_P = 60.0
# b11 ; λ_B = 63.93 ; λ_P = 70.06
# b11 ; λ_B = 56.345 ; λ_P = 54.89
# b11 ; λ_B = 48.815 ; λ_P = 39.83
# b11 ; λ_B = 54.144999999999996 ; λ_P = 50.49
# w1 we4
# b12 ; λ_B = 65.22 ; λ_P = 66.04
# b12 ; λ_B = 70.69 ; λ_P = 76.98
# b12 ; λ_B = 62.99 ; λ_P = 61.58
# b12 ; λ_B = 35.875 ; λ_P = 7.35
# b12 ; λ_B = 52.99 ; λ_P = 41.58
# b12 ; λ_B = 60.295 ; λ_P = 56.19
# b12 ; λ_B = 59.125 ; λ_P = 53.85
# b12 ; λ_B = 62.21000000000001 ; λ_P = 60.02
# b12 ; λ_B = 73.17500000000001 ; λ_P = 81.95
# b12 ; λ_B = 47.445 ; λ_P = 30.49
# b12 ; λ_B = 64.68 ; λ_P = 64.96
# b12 ; λ_B = 58.550000000000004 ; λ_P = 52.7
# b12 ; λ_B = 59.980000000000004 ; λ_P = 55.56
# b12 ; λ_B = 61.465 ; λ_P = 58.53
# b12 ; λ_B = 58.865 ; λ_P = 53.33
# b12 ; λ_B = 56.5 ; λ_P = 48.6
# b12 ; λ_B = 62.2 ; λ_P = 60.0
# b12 ; λ_B = 67.23 ; λ_P = 70.06
# b12 ; λ_B = 59.645 ; λ_P = 54.89
# b12 ; λ_B = 52.115 ; λ_P = 39.83
# b12 ; λ_B = 57.44500000000001 ; λ_P = 50.49
#
# w2 we1
# b1 ; λ_B = 72.235 ; λ_P = 90.07
# b1 ; λ_B = 46.565 ; λ_P = 38.73
# b1 ; λ_B = 69.22 ; λ_P = 84.04
# b1 ; λ_B = 45.2 ; λ_P = 36.0
# b1 ; λ_B = 50.41 ; λ_P = 46.42
# b1 ; λ_B = 64.685 ; λ_P = 74.97
# b1 ; λ_B = 52.58 ; λ_P = 50.76
# b1 ; λ_B = 34.705 ; λ_P = 15.01
# b1 ; λ_B = 71.7 ; λ_P = 89.0
# b1 ; λ_B = 51.08 ; λ_P = 47.76
# b1 ; λ_B = 56.53 ; λ_P = 58.66
# b1 ; λ_B = 57.54 ; λ_P = 60.68
# b1 ; λ_B = 62.745000000000005 ; λ_P = 71.09
# b1 ; λ_B = 58.724999999999994 ; λ_P = 63.05
# b1 ; λ_B = 77.62 ; λ_P = 100.84
# b1 ; λ_B = 48.205 ; λ_P = 42.01
# b1 ; λ_B = 57.16 ; λ_P = 59.92
# b1 ; λ_B = 60.565 ; λ_P = 66.73
# b1 ; λ_B = 53.45 ; λ_P = 52.5
# b1 ; λ_B = 60.19 ; λ_P = 65.98
# b1 ; λ_B = 51.849999999999994 ; λ_P = 49.3
# w2 we1
# b2 ; λ_B = 79.085 ; λ_P = 90.07
# b2 ; λ_B = 53.41499999999999 ; λ_P = 38.73
# b2 ; λ_B = 76.07 ; λ_P = 84.04
# b2 ; λ_B = 52.05 ; λ_P = 36.0
# b2 ; λ_B = 57.26 ; λ_P = 46.42
# b2 ; λ_B = 71.535 ; λ_P = 74.97
# b2 ; λ_B = 59.42999999999999 ; λ_P = 50.76
# b2 ; λ_B = 41.555 ; λ_P = 15.01
# b2 ; λ_B = 78.55 ; λ_P = 89.0
# b2 ; λ_B = 57.92999999999999 ; λ_P = 47.76
# b2 ; λ_B = 63.379999999999995 ; λ_P = 58.66
# b2 ; λ_B = 64.39 ; λ_P = 60.68
# b2 ; λ_B = 69.595 ; λ_P = 71.09
# b2 ; λ_B = 65.57499999999999 ; λ_P = 63.05
# b2 ; λ_B = 84.47 ; λ_P = 100.84
# b2 ; λ_B = 55.05499999999999 ; λ_P = 42.01
# b2 ; λ_B = 64.00999999999999 ; λ_P = 59.92
# b2 ; λ_B = 67.41499999999999 ; λ_P = 66.73
# b2 ; λ_B = 60.3 ; λ_P = 52.5
# b2 ; λ_B = 67.03999999999999 ; λ_P = 65.98
# b2 ; λ_B = 58.699999999999996 ; λ_P = 49.3
# w2 we1
# b3 ; λ_B = 72.735 ; λ_P = 90.07
# b3 ; λ_B = 47.065 ; λ_P = 38.73
# b3 ; λ_B = 69.72 ; λ_P = 84.04
# b3 ; λ_B = 45.7 ; λ_P = 36.0
# b3 ; λ_B = 50.91 ; λ_P = 46.42
# b3 ; λ_B = 65.185 ; λ_P = 74.97
# b3 ; λ_B = 53.08 ; λ_P = 50.76
# b3 ; λ_B = 35.205 ; λ_P = 15.01
# b3 ; λ_B = 72.2 ; λ_P = 89.0
# b3 ; λ_B = 51.58 ; λ_P = 47.76
# b3 ; λ_B = 57.03 ; λ_P = 58.66
# b3 ; λ_B = 58.04 ; λ_P = 60.68
# b3 ; λ_B = 63.245000000000005 ; λ_P = 71.09
# b3 ; λ_B = 59.224999999999994 ; λ_P = 63.05
# b3 ; λ_B = 78.12 ; λ_P = 100.84
# b3 ; λ_B = 48.705 ; λ_P = 42.01
# b3 ; λ_B = 57.66 ; λ_P = 59.92
# b3 ; λ_B = 61.065 ; λ_P = 66.73
# b3 ; λ_B = 53.95 ; λ_P = 52.5
# b3 ; λ_B = 60.69 ; λ_P = 65.98
# b3 ; λ_B = 52.349999999999994 ; λ_P = 49.3
# w2 we1
# b4 ; λ_B = 77.085 ; λ_P = 90.07
# b4 ; λ_B = 51.41499999999999 ; λ_P = 38.73
# b4 ; λ_B = 74.07 ; λ_P = 84.04
# b4 ; λ_B = 50.05 ; λ_P = 36.0
# b4 ; λ_B = 55.26 ; λ_P = 46.42
# b4 ; λ_B = 69.535 ; λ_P = 74.97
# b4 ; λ_B = 57.42999999999999 ; λ_P = 50.76
# b4 ; λ_B = 39.555 ; λ_P = 15.01
# b4 ; λ_B = 76.55 ; λ_P = 89.0
# b4 ; λ_B = 55.92999999999999 ; λ_P = 47.76
# b4 ; λ_B = 61.379999999999995 ; λ_P = 58.66
# b4 ; λ_B = 62.39 ; λ_P = 60.68
# b4 ; λ_B = 67.595 ; λ_P = 71.09
# b4 ; λ_B = 63.574999999999996 ; λ_P = 63.05
# b4 ; λ_B = 82.47 ; λ_P = 100.84
# b4 ; λ_B = 53.05499999999999 ; λ_P = 42.01
# b4 ; λ_B = 62.01 ; λ_P = 59.92
# b4 ; λ_B = 65.41499999999999 ; λ_P = 66.73
# b4 ; λ_B = 58.3 ; λ_P = 52.5
# b4 ; λ_B = 65.03999999999999 ; λ_P = 65.98
# b4 ; λ_B = 56.699999999999996 ; λ_P = 49.3
# w2 we1
# b5 ; λ_B = 67.985 ; λ_P = 90.07
# b5 ; λ_B = 42.315 ; λ_P = 38.73
# b5 ; λ_B = 64.97 ; λ_P = 84.04
# b5 ; λ_B = 40.95 ; λ_P = 36.0
# b5 ; λ_B = 46.16 ; λ_P = 46.42
# b5 ; λ_B = 60.435 ; λ_P = 74.97
# b5 ; λ_B = 48.33 ; λ_P = 50.76
# b5 ; λ_B = 30.455 ; λ_P = 15.01
# b5 ; λ_B = 67.45 ; λ_P = 89.0
# b5 ; λ_B = 46.83 ; λ_P = 47.76
# b5 ; λ_B = 52.28 ; λ_P = 58.66
# b5 ; λ_B = 53.29 ; λ_P = 60.68
# b5 ; λ_B = 58.495000000000005 ; λ_P = 71.09
# b5 ; λ_B = 54.474999999999994 ; λ_P = 63.05
# b5 ; λ_B = 73.37 ; λ_P = 100.84
# b5 ; λ_B = 43.955 ; λ_P = 42.01
# b5 ; λ_B = 52.91 ; λ_P = 59.92
# b5 ; λ_B = 56.315 ; λ_P = 66.73
# b5 ; λ_B = 49.2 ; λ_P = 52.5
# b5 ; λ_B = 55.94 ; λ_P = 65.98
# b5 ; λ_B = 47.599999999999994 ; λ_P = 49.3
# w2 we1
# b6 ; λ_B = 73.035 ; λ_P = 90.07
# b6 ; λ_B = 47.364999999999995 ; λ_P = 38.73
# b6 ; λ_B = 70.02000000000001 ; λ_P = 84.04
# b6 ; λ_B = 46.0 ; λ_P = 36.0
# b6 ; λ_B = 51.21 ; λ_P = 46.42
# b6 ; λ_B = 65.485 ; λ_P = 74.97
# b6 ; λ_B = 53.379999999999995 ; λ_P = 50.76
# b6 ; λ_B = 35.505 ; λ_P = 15.01
# b6 ; λ_B = 72.5 ; λ_P = 89.0
# b6 ; λ_B = 51.879999999999995 ; λ_P = 47.76
# b6 ; λ_B = 57.33 ; λ_P = 58.66
# b6 ; λ_B = 58.34 ; λ_P = 60.68
# b6 ; λ_B = 63.545 ; λ_P = 71.09
# b6 ; λ_B = 59.525 ; λ_P = 63.05
# b6 ; λ_B = 78.42 ; λ_P = 100.84
# b6 ; λ_B = 49.004999999999995 ; λ_P = 42.01
# b6 ; λ_B = 57.96 ; λ_P = 59.92
# b6 ; λ_B = 61.365 ; λ_P = 66.73
# b6 ; λ_B = 54.25 ; λ_P = 52.5
# b6 ; λ_B = 60.99 ; λ_P = 65.98
# b6 ; λ_B = 52.65 ; λ_P = 49.3
#
# w2 we2
# b1 ; λ_B = 68.27 ; λ_P = 82.14
# b1 ; λ_B = 48.01 ; λ_P = 41.62
# b1 ; λ_B = 47.675 ; λ_P = 40.95
# b1 ; λ_B = 55.56 ; λ_P = 56.72
# b1 ; λ_B = 56.39 ; λ_P = 58.38
# b1 ; λ_B = 60.045 ; λ_P = 65.69
# b1 ; λ_B = 56.67 ; λ_P = 58.94
# b1 ; λ_B = -6.800000000000001 ; λ_P = -68.0
# b1 ; λ_B = 54.655 ; λ_P = 54.91
# b1 ; λ_B = 62.235 ; λ_P = 70.07
# b1 ; λ_B = 59.135 ; λ_P = 63.87
# b1 ; λ_B = 69.41 ; λ_P = 84.42
# b1 ; λ_B = 69.065 ; λ_P = 83.73
# b1 ; λ_B = 59.2 ; λ_P = 64.0
# b1 ; λ_B = 54.995000000000005 ; λ_P = 55.59
# b1 ; λ_B = 38.26 ; λ_P = 22.12
# b1 ; λ_B = 53.565 ; λ_P = 52.73
# b1 ; λ_B = 66.865 ; λ_P = 79.33
# b1 ; λ_B = 65.7 ; λ_P = 77.0
# b1 ; λ_B = 51.91 ; λ_P = 49.42
# b1 ; λ_B = 58.33 ; λ_P = 62.26
# w2 we2
# b2 ; λ_B = 75.12 ; λ_P = 82.14
# b2 ; λ_B = 54.86 ; λ_P = 41.62
# b2 ; λ_B = 54.525 ; λ_P = 40.95
# b2 ; λ_B = 62.41 ; λ_P = 56.72
# b2 ; λ_B = 63.239999999999995 ; λ_P = 58.38
# b2 ; λ_B = 66.895 ; λ_P = 65.69
# b2 ; λ_B = 63.519999999999996 ; λ_P = 58.94
# b2 ; λ_B = 0.04999999999999716 ; λ_P = -68.0
# b2 ; λ_B = 61.504999999999995 ; λ_P = 54.91
# b2 ; λ_B = 69.085 ; λ_P = 70.07
# b2 ; λ_B = 65.985 ; λ_P = 63.87
# b2 ; λ_B = 76.25999999999999 ; λ_P = 84.42
# b2 ; λ_B = 75.91499999999999 ; λ_P = 83.73
# b2 ; λ_B = 66.05 ; λ_P = 64.0
# b2 ; λ_B = 61.845 ; λ_P = 55.59
# b2 ; λ_B = 45.11 ; λ_P = 22.12
# b2 ; λ_B = 60.41499999999999 ; λ_P = 52.73
# b2 ; λ_B = 73.715 ; λ_P = 79.33
# b2 ; λ_B = 72.55 ; λ_P = 77.0
# b2 ; λ_B = 58.76 ; λ_P = 49.42
# b2 ; λ_B = 65.17999999999999 ; λ_P = 62.26
# w2 we2
# b3 ; λ_B = 68.77 ; λ_P = 82.14
# b3 ; λ_B = 48.51 ; λ_P = 41.62
# b3 ; λ_B = 48.175 ; λ_P = 40.95
# b3 ; λ_B = 56.06 ; λ_P = 56.72
# b3 ; λ_B = 56.89 ; λ_P = 58.38
# b3 ; λ_B = 60.545 ; λ_P = 65.69
# b3 ; λ_B = 57.17 ; λ_P = 58.94
# b3 ; λ_B = -6.300000000000001 ; λ_P = -68.0
# b3 ; λ_B = 55.155 ; λ_P = 54.91
# b3 ; λ_B = 62.735 ; λ_P = 70.07
# b3 ; λ_B = 59.635 ; λ_P = 63.87
# b3 ; λ_B = 69.91 ; λ_P = 84.42
# b3 ; λ_B = 69.565 ; λ_P = 83.73
# b3 ; λ_B = 59.7 ; λ_P = 64.0
# b3 ; λ_B = 55.495000000000005 ; λ_P = 55.59
# b3 ; λ_B = 38.76 ; λ_P = 22.12
# b3 ; λ_B = 54.065 ; λ_P = 52.73
# b3 ; λ_B = 67.365 ; λ_P = 79.33
# b3 ; λ_B = 66.2 ; λ_P = 77.0
# b3 ; λ_B = 52.41 ; λ_P = 49.42
# b3 ; λ_B = 58.83 ; λ_P = 62.26
# w2 we2
# b4 ; λ_B = 73.12 ; λ_P = 82.14
# b4 ; λ_B = 52.86 ; λ_P = 41.62
# b4 ; λ_B = 52.525 ; λ_P = 40.95
# b4 ; λ_B = 60.41 ; λ_P = 56.72
# b4 ; λ_B = 61.239999999999995 ; λ_P = 58.38
# b4 ; λ_B = 64.895 ; λ_P = 65.69
# b4 ; λ_B = 61.519999999999996 ; λ_P = 58.94
# b4 ; λ_B = -1.9500000000000028 ; λ_P = -68.0
# b4 ; λ_B = 59.504999999999995 ; λ_P = 54.91
# b4 ; λ_B = 67.085 ; λ_P = 70.07
# b4 ; λ_B = 63.985 ; λ_P = 63.87
# b4 ; λ_B = 74.25999999999999 ; λ_P = 84.42
# b4 ; λ_B = 73.91499999999999 ; λ_P = 83.73
# b4 ; λ_B = 64.05 ; λ_P = 64.0
# b4 ; λ_B = 59.845 ; λ_P = 55.59
# b4 ; λ_B = 43.11 ; λ_P = 22.12
# b4 ; λ_B = 58.41499999999999 ; λ_P = 52.73
# b4 ; λ_B = 71.715 ; λ_P = 79.33
# b4 ; λ_B = 70.55 ; λ_P = 77.0
# b4 ; λ_B = 56.76 ; λ_P = 49.42
# b4 ; λ_B = 63.17999999999999 ; λ_P = 62.26
# w2 we2
# b7 ; λ_B = 69.42 ; λ_P = 82.14
# b7 ; λ_B = 49.16 ; λ_P = 41.62
# b7 ; λ_B = 48.825 ; λ_P = 40.95
# b7 ; λ_B = 56.71 ; λ_P = 56.72
# b7 ; λ_B = 57.540000000000006 ; λ_P = 58.38
# b7 ; λ_B = 61.195 ; λ_P = 65.69
# b7 ; λ_B = 57.82 ; λ_P = 58.94
# b7 ; λ_B = -5.649999999999999 ; λ_P = -68.0
# b7 ; λ_B = 55.805 ; λ_P = 54.91
# b7 ; λ_B = 63.385 ; λ_P = 70.07
# b7 ; λ_B = 60.285 ; λ_P = 63.87
# b7 ; λ_B = 70.56 ; λ_P = 84.42
# b7 ; λ_B = 70.215 ; λ_P = 83.73
# b7 ; λ_B = 60.35 ; λ_P = 64.0
# b7 ; λ_B = 56.145 ; λ_P = 55.59
# b7 ; λ_B = 39.410000000000004 ; λ_P = 22.12
# b7 ; λ_B = 54.715 ; λ_P = 52.73
# b7 ; λ_B = 68.015 ; λ_P = 79.33
# b7 ; λ_B = 66.85 ; λ_P = 77.0
# b7 ; λ_B = 53.06 ; λ_P = 49.42
# b7 ; λ_B = 59.480000000000004 ; λ_P = 62.26
# w2 we2
# b8 ; λ_B = 72.67 ; λ_P = 82.14
# b8 ; λ_B = 52.41 ; λ_P = 41.62
# b8 ; λ_B = 52.075 ; λ_P = 40.95
# b8 ; λ_B = 59.96 ; λ_P = 56.72
# b8 ; λ_B = 60.790000000000006 ; λ_P = 58.38
# b8 ; λ_B = 64.445 ; λ_P = 65.69
# b8 ; λ_B = 61.07 ; λ_P = 58.94
# b8 ; λ_B = -2.3999999999999986 ; λ_P = -68.0
# b8 ; λ_B = 59.055 ; λ_P = 54.91
# b8 ; λ_B = 66.63499999999999 ; λ_P = 70.07
# b8 ; λ_B = 63.535 ; λ_P = 63.87
# b8 ; λ_B = 73.81 ; λ_P = 84.42
# b8 ; λ_B = 73.465 ; λ_P = 83.73
# b8 ; λ_B = 63.6 ; λ_P = 64.0
# b8 ; λ_B = 59.395 ; λ_P = 55.59
# b8 ; λ_B = 42.660000000000004 ; λ_P = 22.12
# b8 ; λ_B = 57.965 ; λ_P = 52.73
# b8 ; λ_B = 71.265 ; λ_P = 79.33
# b8 ; λ_B = 70.1 ; λ_P = 77.0
# b8 ; λ_B = 56.31 ; λ_P = 49.42
# b8 ; λ_B = 62.730000000000004 ; λ_P = 62.26
#
# w2 we3
# b1 ; λ_B = 55.76 ; λ_P = 57.12
# b1 ; λ_B = 20.145 ; λ_P = -14.11
# b1 ; λ_B = 72.265 ; λ_P = 90.13
# b1 ; λ_B = 52.224999999999994 ; λ_P = 50.05
# b1 ; λ_B = 51.769999999999996 ; λ_P = 49.14
# b1 ; λ_B = 58.65 ; λ_P = 62.9
# b1 ; λ_B = 49.545 ; λ_P = 44.69
# b1 ; λ_B = 61.19 ; λ_P = 67.98
# b1 ; λ_B = 61.2 ; λ_P = 68.0
# b1 ; λ_B = 71.835 ; λ_P = 89.27
# b1 ; λ_B = 41.68 ; λ_P = 28.96
# b1 ; λ_B = 64.42 ; λ_P = 74.44
# b1 ; λ_B = 70.17 ; λ_P = 85.94
# b1 ; λ_B = 36.945 ; λ_P = 19.49
# b1 ; λ_B = 70.55 ; λ_P = 86.7
# b1 ; λ_B = 50.905 ; λ_P = 47.41
# b1 ; λ_B = 67.9 ; λ_P = 81.4
# b1 ; λ_B = 67.7 ; λ_P = 81.0
# b1 ; λ_B = 68.98 ; λ_P = 83.56
# b1 ; λ_B = 52.19 ; λ_P = 49.98
# b1 ; λ_B = 64.7 ; λ_P = 75.0
# w2 we3
# b2 ; λ_B = 62.61 ; λ_P = 57.12
# b2 ; λ_B = 26.994999999999997 ; λ_P = -14.11
# b2 ; λ_B = 79.115 ; λ_P = 90.13
# b2 ; λ_B = 59.074999999999996 ; λ_P = 50.05
# b2 ; λ_B = 58.62 ; λ_P = 49.14
# b2 ; λ_B = 65.5 ; λ_P = 62.9
# b2 ; λ_B = 56.394999999999996 ; λ_P = 44.69
# b2 ; λ_B = 68.03999999999999 ; λ_P = 67.98
# b2 ; λ_B = 68.05 ; λ_P = 68.0
# b2 ; λ_B = 78.685 ; λ_P = 89.27
# b2 ; λ_B = 48.53 ; λ_P = 28.96
# b2 ; λ_B = 71.27 ; λ_P = 74.44
# b2 ; λ_B = 77.02 ; λ_P = 85.94
# b2 ; λ_B = 43.794999999999995 ; λ_P = 19.49
# b2 ; λ_B = 77.4 ; λ_P = 86.7
# b2 ; λ_B = 57.754999999999995 ; λ_P = 47.41
# b2 ; λ_B = 74.75 ; λ_P = 81.4
# b2 ; λ_B = 74.55 ; λ_P = 81.0
# b2 ; λ_B = 75.83 ; λ_P = 83.56
# b2 ; λ_B = 59.03999999999999 ; λ_P = 49.98
# b2 ; λ_B = 71.55 ; λ_P = 75.0
# w2 we3
# b3 ; λ_B = 56.26 ; λ_P = 57.12
# b3 ; λ_B = 20.645 ; λ_P = -14.11
# b3 ; λ_B = 72.765 ; λ_P = 90.13
# b3 ; λ_B = 52.724999999999994 ; λ_P = 50.05
# b3 ; λ_B = 52.269999999999996 ; λ_P = 49.14
# b3 ; λ_B = 59.15 ; λ_P = 62.9
# b3 ; λ_B = 50.045 ; λ_P = 44.69
# b3 ; λ_B = 61.69 ; λ_P = 67.98
# b3 ; λ_B = 61.7 ; λ_P = 68.0
# b3 ; λ_B = 72.335 ; λ_P = 89.27
# b3 ; λ_B = 42.18 ; λ_P = 28.96
# b3 ; λ_B = 64.92 ; λ_P = 74.44
# b3 ; λ_B = 70.67 ; λ_P = 85.94
# b3 ; λ_B = 37.445 ; λ_P = 19.49
# b3 ; λ_B = 71.05 ; λ_P = 86.7
# b3 ; λ_B = 51.405 ; λ_P = 47.41
# b3 ; λ_B = 68.4 ; λ_P = 81.4
# b3 ; λ_B = 68.2 ; λ_P = 81.0
# b3 ; λ_B = 69.48 ; λ_P = 83.56
# b3 ; λ_B = 52.69 ; λ_P = 49.98
# b3 ; λ_B = 65.2 ; λ_P = 75.0
# w2 we3
# b4 ; λ_B = 60.61 ; λ_P = 57.12
# b4 ; λ_B = 24.994999999999997 ; λ_P = -14.11
# b4 ; λ_B = 77.115 ; λ_P = 90.13
# b4 ; λ_B = 57.074999999999996 ; λ_P = 50.05
# b4 ; λ_B = 56.62 ; λ_P = 49.14
# b4 ; λ_B = 63.5 ; λ_P = 62.9
# b4 ; λ_B = 54.394999999999996 ; λ_P = 44.69
# b4 ; λ_B = 66.03999999999999 ; λ_P = 67.98
# b4 ; λ_B = 66.05 ; λ_P = 68.0
# b4 ; λ_B = 76.685 ; λ_P = 89.27
# b4 ; λ_B = 46.53 ; λ_P = 28.96
# b4 ; λ_B = 69.27 ; λ_P = 74.44
# b4 ; λ_B = 75.02 ; λ_P = 85.94
# b4 ; λ_B = 41.794999999999995 ; λ_P = 19.49
# b4 ; λ_B = 75.4 ; λ_P = 86.7
# b4 ; λ_B = 55.754999999999995 ; λ_P = 47.41
# b4 ; λ_B = 72.75 ; λ_P = 81.4
# b4 ; λ_B = 72.55 ; λ_P = 81.0
# b4 ; λ_B = 73.83 ; λ_P = 83.56
# b4 ; λ_B = 57.03999999999999 ; λ_P = 49.98
# b4 ; λ_B = 69.55 ; λ_P = 75.0
# w2 we3
# b9 ; λ_B = 57.26 ; λ_P = 57.12
# b9 ; λ_B = 21.645 ; λ_P = -14.11
# b9 ; λ_B = 73.765 ; λ_P = 90.13
# b9 ; λ_B = 53.724999999999994 ; λ_P = 50.05
# b9 ; λ_B = 53.269999999999996 ; λ_P = 49.14
# b9 ; λ_B = 60.15 ; λ_P = 62.9
# b9 ; λ_B = 51.045 ; λ_P = 44.69
# b9 ; λ_B = 62.69 ; λ_P = 67.98
# b9 ; λ_B = 62.7 ; λ_P = 68.0
# b9 ; λ_B = 73.335 ; λ_P = 89.27
# b9 ; λ_B = 43.18 ; λ_P = 28.96
# b9 ; λ_B = 65.92 ; λ_P = 74.44
# b9 ; λ_B = 71.67 ; λ_P = 85.94
# b9 ; λ_B = 38.445 ; λ_P = 19.49
# b9 ; λ_B = 72.05 ; λ_P = 86.7
# b9 ; λ_B = 52.405 ; λ_P = 47.41
# b9 ; λ_B = 69.4 ; λ_P = 81.4
# b9 ; λ_B = 69.2 ; λ_P = 81.0
# b9 ; λ_B = 70.48 ; λ_P = 83.56
# b9 ; λ_B = 53.69 ; λ_P = 49.98
# b9 ; λ_B = 66.2 ; λ_P = 75.0
# w2 we3
# b10 ; λ_B = 60.61 ; λ_P = 57.12
# b10 ; λ_B = 24.994999999999997 ; λ_P = -14.11
# b10 ; λ_B = 77.115 ; λ_P = 90.13
# b10 ; λ_B = 57.074999999999996 ; λ_P = 50.05
# b10 ; λ_B = 56.62 ; λ_P = 49.14
# b10 ; λ_B = 63.5 ; λ_P = 62.9
# b10 ; λ_B = 54.394999999999996 ; λ_P = 44.69
# b10 ; λ_B = 66.03999999999999 ; λ_P = 67.98
# b10 ; λ_B = 66.05 ; λ_P = 68.0
# b10 ; λ_B = 76.685 ; λ_P = 89.27
# b10 ; λ_B = 46.53 ; λ_P = 28.96
# b10 ; λ_B = 69.27 ; λ_P = 74.44
# b10 ; λ_B = 75.02 ; λ_P = 85.94
# b10 ; λ_B = 41.794999999999995 ; λ_P = 19.49
# b10 ; λ_B = 75.4 ; λ_P = 86.7
# b10 ; λ_B = 55.754999999999995 ; λ_P = 47.41
# b10 ; λ_B = 72.75 ; λ_P = 81.4
# b10 ; λ_B = 72.55 ; λ_P = 81.0
# b10 ; λ_B = 73.83 ; λ_P = 83.56
# b10 ; λ_B = 57.03999999999999 ; λ_P = 49.98
# b10 ; λ_B = 69.55 ; λ_P = 75.0
#
# w2 we4
# b1 ; λ_B = 50.055 ; λ_P = 45.71
# b1 ; λ_B = 52.724999999999994 ; λ_P = 51.05
# b1 ; λ_B = 54.599999999999994 ; λ_P = 54.8
# b1 ; λ_B = 60.7 ; λ_P = 67.0
# b1 ; λ_B = 58.195 ; λ_P = 61.99
# b1 ; λ_B = 62.870000000000005 ; λ_P = 71.34
# b1 ; λ_B = 53.455 ; λ_P = 52.51
# b1 ; λ_B = 57.935 ; λ_P = 61.47
# b1 ; λ_B = 51.91 ; λ_P = 49.42
# b1 ; λ_B = 50.28 ; λ_P = 46.16
# b1 ; λ_B = 56.45 ; λ_P = 58.5
# b1 ; λ_B = 22.465 ; λ_P = -9.47
# b1 ; λ_B = 53.65 ; λ_P = 52.9
# b1 ; λ_B = 51.4 ; λ_P = 48.4
# b1 ; λ_B = 62.67999999999999 ; λ_P = 70.96
# b1 ; λ_B = 50.14 ; λ_P = 45.88
# b1 ; λ_B = 69.28 ; λ_P = 84.16
# b1 ; λ_B = 56.665 ; λ_P = 58.93
# b1 ; λ_B = 53.58 ; λ_P = 52.76
# b1 ; λ_B = 59.185 ; λ_P = 63.97
# b1 ; λ_B = 66.66 ; λ_P = 78.92
# w2 we4
# b2 ; λ_B = 56.905 ; λ_P = 45.71
# b2 ; λ_B = 59.574999999999996 ; λ_P = 51.05
# b2 ; λ_B = 61.449999999999996 ; λ_P = 54.8
# b2 ; λ_B = 67.55 ; λ_P = 67.0
# b2 ; λ_B = 65.045 ; λ_P = 61.99
# b2 ; λ_B = 69.72 ; λ_P = 71.34
# b2 ; λ_B = 60.30499999999999 ; λ_P = 52.51
# b2 ; λ_B = 64.785 ; λ_P = 61.47
# b2 ; λ_B = 58.76 ; λ_P = 49.42
# b2 ; λ_B = 57.129999999999995 ; λ_P = 46.16
# b2 ; λ_B = 63.3 ; λ_P = 58.5
# b2 ; λ_B = 29.314999999999998 ; λ_P = -9.47
# b2 ; λ_B = 60.5 ; λ_P = 52.9
# b2 ; λ_B = 58.25 ; λ_P = 48.4
# b2 ; λ_B = 69.53 ; λ_P = 70.96
# b2 ; λ_B = 56.989999999999995 ; λ_P = 45.88
# b2 ; λ_B = 76.13 ; λ_P = 84.16
# b2 ; λ_B = 63.515 ; λ_P = 58.93
# b2 ; λ_B = 60.42999999999999 ; λ_P = 52.76
# b2 ; λ_B = 66.035 ; λ_P = 63.97
# b2 ; λ_B = 73.50999999999999 ; λ_P = 78.92
# w2 we4
# b3 ; λ_B = 50.555 ; λ_P = 45.71
# b3 ; λ_B = 53.224999999999994 ; λ_P = 51.05
# b3 ; λ_B = 55.099999999999994 ; λ_P = 54.8
# b3 ; λ_B = 61.2 ; λ_P = 67.0
# b3 ; λ_B = 58.695 ; λ_P = 61.99
# b3 ; λ_B = 63.370000000000005 ; λ_P = 71.34
# b3 ; λ_B = 53.955 ; λ_P = 52.51
# b3 ; λ_B = 58.435 ; λ_P = 61.47
# b3 ; λ_B = 52.41 ; λ_P = 49.42
# b3 ; λ_B = 50.78 ; λ_P = 46.16
# b3 ; λ_B = 56.95 ; λ_P = 58.5
# b3 ; λ_B = 22.965 ; λ_P = -9.47
# b3 ; λ_B = 54.15 ; λ_P = 52.9
# b3 ; λ_B = 51.9 ; λ_P = 48.4
# b3 ; λ_B = 63.17999999999999 ; λ_P = 70.96
# b3 ; λ_B = 50.64 ; λ_P = 45.88
# b3 ; λ_B = 69.78 ; λ_P = 84.16
# b3 ; λ_B = 57.165 ; λ_P = 58.93
# b3 ; λ_B = 54.08 ; λ_P = 52.76
# b3 ; λ_B = 59.685 ; λ_P = 63.97
# b3 ; λ_B = 67.16 ; λ_P = 78.92
# w2 we4
# b4 ; λ_B = 54.905 ; λ_P = 45.71
# b4 ; λ_B = 57.574999999999996 ; λ_P = 51.05
# b4 ; λ_B = 59.449999999999996 ; λ_P = 54.8
# b4 ; λ_B = 65.55 ; λ_P = 67.0
# b4 ; λ_B = 63.045 ; λ_P = 61.99
# b4 ; λ_B = 67.72 ; λ_P = 71.34
# b4 ; λ_B = 58.30499999999999 ; λ_P = 52.51
# b4 ; λ_B = 62.785 ; λ_P = 61.47
# b4 ; λ_B = 56.76 ; λ_P = 49.42
# b4 ; λ_B = 55.129999999999995 ; λ_P = 46.16
# b4 ; λ_B = 61.3 ; λ_P = 58.5
# b4 ; λ_B = 27.314999999999998 ; λ_P = -9.47
# b4 ; λ_B = 58.5 ; λ_P = 52.9
# b4 ; λ_B = 56.25 ; λ_P = 48.4
# b4 ; λ_B = 67.53 ; λ_P = 70.96
# b4 ; λ_B = 54.989999999999995 ; λ_P = 45.88
# b4 ; λ_B = 74.13 ; λ_P = 84.16
# b4 ; λ_B = 61.515 ; λ_P = 58.93
# b4 ; λ_B = 58.42999999999999 ; λ_P = 52.76
# b4 ; λ_B = 64.035 ; λ_P = 63.97
# b4 ; λ_B = 71.50999999999999 ; λ_P = 78.92
# w2 we4
# b11 ; λ_B = 51.754999999999995 ; λ_P = 45.71
# b11 ; λ_B = 54.425 ; λ_P = 51.05
# b11 ; λ_B = 56.3 ; λ_P = 54.8
# b11 ; λ_B = 62.4 ; λ_P = 67.0
# b11 ; λ_B = 59.894999999999996 ; λ_P = 61.99
# b11 ; λ_B = 64.57 ; λ_P = 71.34
# b11 ; λ_B = 55.155 ; λ_P = 52.51
# b11 ; λ_B = 59.635 ; λ_P = 61.47
# b11 ; λ_B = 53.61 ; λ_P = 49.42
# b11 ; λ_B = 51.98 ; λ_P = 46.16
# b11 ; λ_B = 58.15 ; λ_P = 58.5
# b11 ; λ_B = 24.165 ; λ_P = -9.47
# b11 ; λ_B = 55.349999999999994 ; λ_P = 52.9
# b11 ; λ_B = 53.099999999999994 ; λ_P = 48.4
# b11 ; λ_B = 64.38 ; λ_P = 70.96
# b11 ; λ_B = 51.84 ; λ_P = 45.88
# b11 ; λ_B = 70.97999999999999 ; λ_P = 84.16
# b11 ; λ_B = 58.364999999999995 ; λ_P = 58.93
# b11 ; λ_B = 55.28 ; λ_P = 52.76
# b11 ; λ_B = 60.885 ; λ_P = 63.97
# b11 ; λ_B = 68.36 ; λ_P = 78.92
# w2 we4
# b12 ; λ_B = 55.05500000000001 ; λ_P = 45.71
# b12 ; λ_B = 57.725 ; λ_P = 51.05
# b12 ; λ_B = 59.6 ; λ_P = 54.8
# b12 ; λ_B = 65.7 ; λ_P = 67.0
# b12 ; λ_B = 63.19500000000001 ; λ_P = 61.99
# b12 ; λ_B = 67.87 ; λ_P = 71.34
# b12 ; λ_B = 58.455 ; λ_P = 52.51
# b12 ; λ_B = 62.935 ; λ_P = 61.47
# b12 ; λ_B = 56.910000000000004 ; λ_P = 49.42
# b12 ; λ_B = 55.28 ; λ_P = 46.16
# b12 ; λ_B = 61.45 ; λ_P = 58.5
# b12 ; λ_B = 27.465000000000003 ; λ_P = -9.47
# b12 ; λ_B = 58.650000000000006 ; λ_P = 52.9
# b12 ; λ_B = 56.400000000000006 ; λ_P = 48.4
# b12 ; λ_B = 67.68 ; λ_P = 70.96
# b12 ; λ_B = 55.14 ; λ_P = 45.88
# b12 ; λ_B = 74.28 ; λ_P = 84.16
# b12 ; λ_B = 61.665000000000006 ; λ_P = 58.93
# b12 ; λ_B = 58.58 ; λ_P = 52.76
# b12 ; λ_B = 64.185 ; λ_P = 63.97
# b12 ; λ_B = 71.66 ; λ_P = 78.92
#
# w3 we1
# b1 ; λ_B = 72.235 ; λ_P = 90.07
# b1 ; λ_B = 46.565 ; λ_P = 38.73
# b1 ; λ_B = 69.22 ; λ_P = 84.04
# b1 ; λ_B = 45.2 ; λ_P = 36.0
# b1 ; λ_B = 50.41 ; λ_P = 46.42
# b1 ; λ_B = 64.685 ; λ_P = 74.97
# b1 ; λ_B = 52.58 ; λ_P = 50.76
# b1 ; λ_B = 34.705 ; λ_P = 15.01
# b1 ; λ_B = 71.7 ; λ_P = 89.0
# b1 ; λ_B = 51.08 ; λ_P = 47.76
# b1 ; λ_B = 56.53 ; λ_P = 58.66
# b1 ; λ_B = 57.54 ; λ_P = 60.68
# b1 ; λ_B = 62.745000000000005 ; λ_P = 71.09
# b1 ; λ_B = 58.724999999999994 ; λ_P = 63.05
# b1 ; λ_B = 77.62 ; λ_P = 100.84
# b1 ; λ_B = 48.205 ; λ_P = 42.01
# b1 ; λ_B = 57.16 ; λ_P = 59.92
# b1 ; λ_B = 60.565 ; λ_P = 66.73
# b1 ; λ_B = 53.45 ; λ_P = 52.5
# b1 ; λ_B = 60.19 ; λ_P = 65.98
# b1 ; λ_B = 51.849999999999994 ; λ_P = 49.3
# w3 we1
# b2 ; λ_B = 79.085 ; λ_P = 90.07
# b2 ; λ_B = 53.41499999999999 ; λ_P = 38.73
# b2 ; λ_B = 76.07 ; λ_P = 84.04
# b2 ; λ_B = 52.05 ; λ_P = 36.0
# b2 ; λ_B = 57.26 ; λ_P = 46.42
# b2 ; λ_B = 71.535 ; λ_P = 74.97
# b2 ; λ_B = 59.42999999999999 ; λ_P = 50.76
# b2 ; λ_B = 41.555 ; λ_P = 15.01
# b2 ; λ_B = 78.55 ; λ_P = 89.0
# b2 ; λ_B = 57.92999999999999 ; λ_P = 47.76
# b2 ; λ_B = 63.379999999999995 ; λ_P = 58.66
# b2 ; λ_B = 64.39 ; λ_P = 60.68
# b2 ; λ_B = 69.595 ; λ_P = 71.09
# b2 ; λ_B = 65.57499999999999 ; λ_P = 63.05
# b2 ; λ_B = 84.47 ; λ_P = 100.84
# b2 ; λ_B = 55.05499999999999 ; λ_P = 42.01
# b2 ; λ_B = 64.00999999999999 ; λ_P = 59.92
# b2 ; λ_B = 67.41499999999999 ; λ_P = 66.73
# b2 ; λ_B = 60.3 ; λ_P = 52.5
# b2 ; λ_B = 67.03999999999999 ; λ_P = 65.98
# b2 ; λ_B = 58.699999999999996 ; λ_P = 49.3
# w3 we1
# b3 ; λ_B = 72.735 ; λ_P = 90.07
# b3 ; λ_B = 47.065 ; λ_P = 38.73
# b3 ; λ_B = 69.72 ; λ_P = 84.04
# b3 ; λ_B = 45.7 ; λ_P = 36.0
# b3 ; λ_B = 50.91 ; λ_P = 46.42
# b3 ; λ_B = 65.185 ; λ_P = 74.97
# b3 ; λ_B = 53.08 ; λ_P = 50.76
# b3 ; λ_B = 35.205 ; λ_P = 15.01
# b3 ; λ_B = 72.2 ; λ_P = 89.0
# b3 ; λ_B = 51.58 ; λ_P = 47.76
# b3 ; λ_B = 57.03 ; λ_P = 58.66
# b3 ; λ_B = 58.04 ; λ_P = 60.68
# b3 ; λ_B = 63.245000000000005 ; λ_P = 71.09
# b3 ; λ_B = 59.224999999999994 ; λ_P = 63.05
# b3 ; λ_B = 78.12 ; λ_P = 100.84
# b3 ; λ_B = 48.705 ; λ_P = 42.01
# b3 ; λ_B = 57.66 ; λ_P = 59.92
# b3 ; λ_B = 61.065 ; λ_P = 66.73
# b3 ; λ_B = 53.95 ; λ_P = 52.5
# b3 ; λ_B = 60.69 ; λ_P = 65.98
# b3 ; λ_B = 52.349999999999994 ; λ_P = 49.3
# w3 we1
# b4 ; λ_B = 77.085 ; λ_P = 90.07
# b4 ; λ_B = 51.41499999999999 ; λ_P = 38.73
# b4 ; λ_B = 74.07 ; λ_P = 84.04
# b4 ; λ_B = 50.05 ; λ_P = 36.0
# b4 ; λ_B = 55.26 ; λ_P = 46.42
# b4 ; λ_B = 69.535 ; λ_P = 74.97
# b4 ; λ_B = 57.42999999999999 ; λ_P = 50.76
# b4 ; λ_B = 39.555 ; λ_P = 15.01
# b4 ; λ_B = 76.55 ; λ_P = 89.0
# b4 ; λ_B = 55.92999999999999 ; λ_P = 47.76
# b4 ; λ_B = 61.379999999999995 ; λ_P = 58.66
# b4 ; λ_B = 62.39 ; λ_P = 60.68
# b4 ; λ_B = 67.595 ; λ_P = 71.09
# b4 ; λ_B = 63.574999999999996 ; λ_P = 63.05
# b4 ; λ_B = 82.47 ; λ_P = 100.84
# b4 ; λ_B = 53.05499999999999 ; λ_P = 42.01
# b4 ; λ_B = 62.01 ; λ_P = 59.92
# b4 ; λ_B = 65.41499999999999 ; λ_P = 66.73
# b4 ; λ_B = 58.3 ; λ_P = 52.5
# b4 ; λ_B = 65.03999999999999 ; λ_P = 65.98
# b4 ; λ_B = 56.699999999999996 ; λ_P = 49.3
# w3 we1
# b5 ; λ_B = 67.985 ; λ_P = 90.07
# b5 ; λ_B = 42.315 ; λ_P = 38.73
# b5 ; λ_B = 64.97 ; λ_P = 84.04
# b5 ; λ_B = 40.95 ; λ_P = 36.0
# b5 ; λ_B = 46.16 ; λ_P = 46.42
# b5 ; λ_B = 60.435 ; λ_P = 74.97
# b5 ; λ_B = 48.33 ; λ_P = 50.76
# b5 ; λ_B = 30.455 ; λ_P = 15.01
# b5 ; λ_B = 67.45 ; λ_P = 89.0
# b5 ; λ_B = 46.83 ; λ_P = 47.76
# b5 ; λ_B = 52.28 ; λ_P = 58.66
# b5 ; λ_B = 53.29 ; λ_P = 60.68
# b5 ; λ_B = 58.495000000000005 ; λ_P = 71.09
# b5 ; λ_B = 54.474999999999994 ; λ_P = 63.05
# b5 ; λ_B = 73.37 ; λ_P = 100.84
# b5 ; λ_B = 43.955 ; λ_P = 42.01
# b5 ; λ_B = 52.91 ; λ_P = 59.92
# b5 ; λ_B = 56.315 ; λ_P = 66.73
# b5 ; λ_B = 49.2 ; λ_P = 52.5
# b5 ; λ_B = 55.94 ; λ_P = 65.98
# b5 ; λ_B = 47.599999999999994 ; λ_P = 49.3
# w3 we1
# b6 ; λ_B = 73.035 ; λ_P = 90.07
# b6 ; λ_B = 47.364999999999995 ; λ_P = 38.73
# b6 ; λ_B = 70.02000000000001 ; λ_P = 84.04
# b6 ; λ_B = 46.0 ; λ_P = 36.0
# b6 ; λ_B = 51.21 ; λ_P = 46.42
# b6 ; λ_B = 65.485 ; λ_P = 74.97
# b6 ; λ_B = 53.379999999999995 ; λ_P = 50.76
# b6 ; λ_B = 35.505 ; λ_P = 15.01
# b6 ; λ_B = 72.5 ; λ_P = 89.0
# b6 ; λ_B = 51.879999999999995 ; λ_P = 47.76
# b6 ; λ_B = 57.33 ; λ_P = 58.66
# b6 ; λ_B = 58.34 ; λ_P = 60.68
# b6 ; λ_B = 63.545 ; λ_P = 71.09
# b6 ; λ_B = 59.525 ; λ_P = 63.05
# b6 ; λ_B = 78.42 ; λ_P = 100.84
# b6 ; λ_B = 49.004999999999995 ; λ_P = 42.01
# b6 ; λ_B = 57.96 ; λ_P = 59.92
# b6 ; λ_B = 61.365 ; λ_P = 66.73
# b6 ; λ_B = 54.25 ; λ_P = 52.5
# b6 ; λ_B = 60.99 ; λ_P = 65.98
# b6 ; λ_B = 52.65 ; λ_P = 49.3
#
# w3 we2
# b1 ; λ_B = 68.27 ; λ_P = 82.14
# b1 ; λ_B = 48.01 ; λ_P = 41.62
# b1 ; λ_B = 47.675 ; λ_P = 40.95
# b1 ; λ_B = 55.56 ; λ_P = 56.72
# b1 ; λ_B = 56.39 ; λ_P = 58.38
# b1 ; λ_B = 60.045 ; λ_P = 65.69
# b1 ; λ_B = 56.67 ; λ_P = 58.94
# b1 ; λ_B = -6.800000000000001 ; λ_P = -68.0
# b1 ; λ_B = 54.655 ; λ_P = 54.91
# b1 ; λ_B = 62.235 ; λ_P = 70.07
# b1 ; λ_B = 59.135 ; λ_P = 63.87
# b1 ; λ_B = 69.41 ; λ_P = 84.42
# b1 ; λ_B = 69.065 ; λ_P = 83.73
# b1 ; λ_B = 59.2 ; λ_P = 64.0
# b1 ; λ_B = 54.995000000000005 ; λ_P = 55.59
# b1 ; λ_B = 38.26 ; λ_P = 22.12
# b1 ; λ_B = 53.565 ; λ_P = 52.73
# b1 ; λ_B = 66.865 ; λ_P = 79.33
# b1 ; λ_B = 65.7 ; λ_P = 77.0
# b1 ; λ_B = 51.91 ; λ_P = 49.42
# b1 ; λ_B = 58.33 ; λ_P = 62.26
# w3 we2
# b2 ; λ_B = 75.12 ; λ_P = 82.14
# b2 ; λ_B = 54.86 ; λ_P = 41.62
# b2 ; λ_B = 54.525 ; λ_P = 40.95
# b2 ; λ_B = 62.41 ; λ_P = 56.72
# b2 ; λ_B = 63.239999999999995 ; λ_P = 58.38
# b2 ; λ_B = 66.895 ; λ_P = 65.69
# b2 ; λ_B = 63.519999999999996 ; λ_P = 58.94
# b2 ; λ_B = 0.04999999999999716 ; λ_P = -68.0
# b2 ; λ_B = 61.504999999999995 ; λ_P = 54.91
# b2 ; λ_B = 69.085 ; λ_P = 70.07
# b2 ; λ_B = 65.985 ; λ_P = 63.87
# b2 ; λ_B = 76.25999999999999 ; λ_P = 84.42
# b2 ; λ_B = 75.91499999999999 ; λ_P = 83.73
# b2 ; λ_B = 66.05 ; λ_P = 64.0
# b2 ; λ_B = 61.845 ; λ_P = 55.59
# b2 ; λ_B = 45.11 ; λ_P = 22.12
# b2 ; λ_B = 60.41499999999999 ; λ_P = 52.73
# b2 ; λ_B = 73.715 ; λ_P = 79.33
# b2 ; λ_B = 72.55 ; λ_P = 77.0
# b2 ; λ_B = 58.76 ; λ_P = 49.42
# b2 ; λ_B = 65.17999999999999 ; λ_P = 62.26
# w3 we2
# b3 ; λ_B = 68.77 ; λ_P = 82.14
# b3 ; λ_B = 48.51 ; λ_P = 41.62
# b3 ; λ_B = 48.175 ; λ_P = 40.95
# b3 ; λ_B = 56.06 ; λ_P = 56.72
# b3 ; λ_B = 56.89 ; λ_P = 58.38
# b3 ; λ_B = 60.545 ; λ_P = 65.69
# b3 ; λ_B = 57.17 ; λ_P = 58.94
# b3 ; λ_B = -6.300000000000001 ; λ_P = -68.0
# b3 ; λ_B = 55.155 ; λ_P = 54.91
# b3 ; λ_B = 62.735 ; λ_P = 70.07
# b3 ; λ_B = 59.635 ; λ_P = 63.87
# b3 ; λ_B = 69.91 ; λ_P = 84.42
# b3 ; λ_B = 69.565 ; λ_P = 83.73
# b3 ; λ_B = 59.7 ; λ_P = 64.0
# b3 ; λ_B = 55.495000000000005 ; λ_P = 55.59
# b3 ; λ_B = 38.76 ; λ_P = 22.12
# b3 ; λ_B = 54.065 ; λ_P = 52.73
# b3 ; λ_B = 67.365 ; λ_P = 79.33
# b3 ; λ_B = 66.2 ; λ_P = 77.0
# b3 ; λ_B = 52.41 ; λ_P = 49.42
# b3 ; λ_B = 58.83 ; λ_P = 62.26
# w3 we2
# b4 ; λ_B = 73.12 ; λ_P = 82.14
# b4 ; λ_B = 52.86 ; λ_P = 41.62
# b4 ; λ_B = 52.525 ; λ_P = 40.95
# b4 ; λ_B = 60.41 ; λ_P = 56.72
# b4 ; λ_B = 61.239999999999995 ; λ_P = 58.38
# b4 ; λ_B = 64.895 ; λ_P = 65.69
# b4 ; λ_B = 61.519999999999996 ; λ_P = 58.94
# b4 ; λ_B = -1.9500000000000028 ; λ_P = -68.0
# b4 ; λ_B = 59.504999999999995 ; λ_P = 54.91
# b4 ; λ_B = 67.085 ; λ_P = 70.07
# b4 ; λ_B = 63.985 ; λ_P = 63.87
# b4 ; λ_B = 74.25999999999999 ; λ_P = 84.42
# b4 ; λ_B = 73.91499999999999 ; λ_P = 83.73
# b4 ; λ_B = 64.05 ; λ_P = 64.0
# b4 ; λ_B = 59.845 ; λ_P = 55.59
# b4 ; λ_B = 43.11 ; λ_P = 22.12
# b4 ; λ_B = 58.41499999999999 ; λ_P = 52.73
# b4 ; λ_B = 71.715 ; λ_P = 79.33
# b4 ; λ_B = 70.55 ; λ_P = 77.0
# b4 ; λ_B = 56.76 ; λ_P = 49.42
# b4 ; λ_B = 63.17999999999999 ; λ_P = 62.26
# w3 we2
# b7 ; λ_B = 69.42 ; λ_P = 82.14
# b7 ; λ_B = 49.16 ; λ_P = 41.62
# b7 ; λ_B = 48.825 ; λ_P = 40.95
# b7 ; λ_B = 56.71 ; λ_P = 56.72
# b7 ; λ_B = 57.540000000000006 ; λ_P = 58.38
# b7 ; λ_B = 61.195 ; λ_P = 65.69
# b7 ; λ_B = 57.82 ; λ_P = 58.94
# b7 ; λ_B = -5.649999999999999 ; λ_P = -68.0
# b7 ; λ_B = 55.805 ; λ_P = 54.91
# b7 ; λ_B = 63.385 ; λ_P = 70.07
# b7 ; λ_B = 60.285 ; λ_P = 63.87
# b7 ; λ_B = 70.56 ; λ_P = 84.42
# b7 ; λ_B = 70.215 ; λ_P = 83.73
# b7 ; λ_B = 60.35 ; λ_P = 64.0
# b7 ; λ_B = 56.145 ; λ_P = 55.59
# b7 ; λ_B = 39.410000000000004 ; λ_P = 22.12
# b7 ; λ_B = 54.715 ; λ_P = 52.73
# b7 ; λ_B = 68.015 ; λ_P = 79.33
# b7 ; λ_B = 66.85 ; λ_P = 77.0
# b7 ; λ_B = 53.06 ; λ_P = 49.42
# b7 ; λ_B = 59.480000000000004 ; λ_P = 62.26
# w3 we2
# b8 ; λ_B = 72.67 ; λ_P = 82.14
# b8 ; λ_B = 52.41 ; λ_P = 41.62
# b8 ; λ_B = 52.075 ; λ_P = 40.95
# b8 ; λ_B = 59.96 ; λ_P = 56.72
# b8 ; λ_B = 60.790000000000006 ; λ_P = 58.38
# b8 ; λ_B = 64.445 ; λ_P = 65.69
# b8 ; λ_B = 61.07 ; λ_P = 58.94
# b8 ; λ_B = -2.3999999999999986 ; λ_P = -68.0
# b8 ; λ_B = 59.055 ; λ_P = 54.91
# b8 ; λ_B = 66.63499999999999 ; λ_P = 70.07
# b8 ; λ_B = 63.535 ; λ_P = 63.87
# b8 ; λ_B = 73.81 ; λ_P = 84.42
# b8 ; λ_B = 73.465 ; λ_P = 83.73
# b8 ; λ_B = 63.6 ; λ_P = 64.0
# b8 ; λ_B = 59.395 ; λ_P = 55.59
# b8 ; λ_B = 42.660000000000004 ; λ_P = 22.12
# b8 ; λ_B = 57.965 ; λ_P = 52.73
# b8 ; λ_B = 71.265 ; λ_P = 79.33
# b8 ; λ_B = 70.1 ; λ_P = 77.0
# b8 ; λ_B = 56.31 ; λ_P = 49.42
# b8 ; λ_B = 62.730000000000004 ; λ_P = 62.26
#
# w3 we3
# b1 ; λ_B = 4.73 ; λ_P = -44.94
# b1 ; λ_B = 43.93 ; λ_P = 33.46
# b1 ; λ_B = 54.84 ; λ_P = 55.28
# b1 ; λ_B = 51.349999999999994 ; λ_P = 48.3
# b1 ; λ_B = 66.715 ; λ_P = 79.03
# b1 ; λ_B = 59.519999999999996 ; λ_P = 64.64
# b1 ; λ_B = 57.78 ; λ_P = 61.16
# b1 ; λ_B = 27.205 ; λ_P = 0.01
# b1 ; λ_B = 49.730000000000004 ; λ_P = 45.06
# b1 ; λ_B = 38.595 ; λ_P = 22.79
# b1 ; λ_B = 53.36 ; λ_P = 52.32
# b1 ; λ_B = 63.254999999999995 ; λ_P = 72.11
# b1 ; λ_B = 48.14 ; λ_P = 41.88
# b1 ; λ_B = 51.004999999999995 ; λ_P = 47.61
# b1 ; λ_B = 69.375 ; λ_P = 84.35
# b1 ; λ_B = 42.915 ; λ_P = 31.43
# b1 ; λ_B = 69.725 ; λ_P = 85.05
# b1 ; λ_B = 66.73 ; λ_P = 79.06
# b1 ; λ_B = 70.15 ; λ_P = 85.9
# b1 ; λ_B = 41.8 ; λ_P = 29.2
# b1 ; λ_B = 53.269999999999996 ; λ_P = 52.14
# w3 we3
# b2 ; λ_B = 11.579999999999998 ; λ_P = -44.94
# b2 ; λ_B = 50.78 ; λ_P = 33.46
# b2 ; λ_B = 61.69 ; λ_P = 55.28
# b2 ; λ_B = 58.199999999999996 ; λ_P = 48.3
# b2 ; λ_B = 73.565 ; λ_P = 79.03
# b2 ; λ_B = 66.37 ; λ_P = 64.64
# b2 ; λ_B = 64.63 ; λ_P = 61.16
# b2 ; λ_B = 34.055 ; λ_P = 0.01
# b2 ; λ_B = 56.58 ; λ_P = 45.06
# b2 ; λ_B = 45.44499999999999 ; λ_P = 22.79
# b2 ; λ_B = 60.209999999999994 ; λ_P = 52.32
# b2 ; λ_B = 70.10499999999999 ; λ_P = 72.11
# b2 ; λ_B = 54.989999999999995 ; λ_P = 41.88
# b2 ; λ_B = 57.855 ; λ_P = 47.61
# b2 ; λ_B = 76.225 ; λ_P = 84.35
# b2 ; λ_B = 49.765 ; λ_P = 31.43
# b2 ; λ_B = 76.57499999999999 ; λ_P = 85.05
# b2 ; λ_B = 73.58 ; λ_P = 79.06
# b2 ; λ_B = 77.0 ; λ_P = 85.9
# b2 ; λ_B = 48.65 ; λ_P = 29.2
# b2 ; λ_B = 60.12 ; λ_P = 52.14
# w3 we3
# b3 ; λ_B = 5.23 ; λ_P = -44.94
# b3 ; λ_B = 44.43 ; λ_P = 33.46
# b3 ; λ_B = 55.34 ; λ_P = 55.28
# b3 ; λ_B = 51.849999999999994 ; λ_P = 48.3
# b3 ; λ_B = 67.215 ; λ_P = 79.03
# b3 ; λ_B = 60.019999999999996 ; λ_P = 64.64
# b3 ; λ_B = 58.28 ; λ_P = 61.16
# b3 ; λ_B = 27.705 ; λ_P = 0.01
# b3 ; λ_B = 50.230000000000004 ; λ_P = 45.06
# b3 ; λ_B = 39.095 ; λ_P = 22.79
# b3 ; λ_B = 53.86 ; λ_P = 52.32
# b3 ; λ_B = 63.754999999999995 ; λ_P = 72.11
# b3 ; λ_B = 48.64 ; λ_P = 41.88
# b3 ; λ_B = 51.504999999999995 ; λ_P = 47.61
# b3 ; λ_B = 69.875 ; λ_P = 84.35
# b3 ; λ_B = 43.415 ; λ_P = 31.43
# b3 ; λ_B = 70.225 ; λ_P = 85.05
# b3 ; λ_B = 67.23 ; λ_P = 79.06
# b3 ; λ_B = 70.65 ; λ_P = 85.9
# b3 ; λ_B = 42.3 ; λ_P = 29.2
# b3 ; λ_B = 53.769999999999996 ; λ_P = 52.14
# w3 we3
# b4 ; λ_B = 9.579999999999998 ; λ_P = -44.94
# b4 ; λ_B = 48.78 ; λ_P = 33.46
# b4 ; λ_B = 59.69 ; λ_P = 55.28
# b4 ; λ_B = 56.199999999999996 ; λ_P = 48.3
# b4 ; λ_B = 71.565 ; λ_P = 79.03
# b4 ; λ_B = 64.37 ; λ_P = 64.64
# b4 ; λ_B = 62.629999999999995 ; λ_P = 61.16
# b4 ; λ_B = 32.055 ; λ_P = 0.01
# b4 ; λ_B = 54.58 ; λ_P = 45.06
# b4 ; λ_B = 43.44499999999999 ; λ_P = 22.79
# b4 ; λ_B = 58.209999999999994 ; λ_P = 52.32
# b4 ; λ_B = 68.10499999999999 ; λ_P = 72.11
# b4 ; λ_B = 52.989999999999995 ; λ_P = 41.88
# b4 ; λ_B = 55.855 ; λ_P = 47.61
# b4 ; λ_B = 74.225 ; λ_P = 84.35
# b4 ; λ_B = 47.765 ; λ_P = 31.43
# b4 ; λ_B = 74.57499999999999 ; λ_P = 85.05
# b4 ; λ_B = 71.58 ; λ_P = 79.06
# b4 ; λ_B = 75.0 ; λ_P = 85.9
# b4 ; λ_B = 46.65 ; λ_P = 29.2
# b4 ; λ_B = 58.12 ; λ_P = 52.14
# w3 we3
# b9 ; λ_B = 6.23 ; λ_P = -44.94
# b9 ; λ_B = 45.43 ; λ_P = 33.46
# b9 ; λ_B = 56.34 ; λ_P = 55.28
# b9 ; λ_B = 52.849999999999994 ; λ_P = 48.3
# b9 ; λ_B = 68.215 ; λ_P = 79.03
# b9 ; λ_B = 61.019999999999996 ; λ_P = 64.64
# b9 ; λ_B = 59.28 ; λ_P = 61.16
# b9 ; λ_B = 28.705 ; λ_P = 0.01
# b9 ; λ_B = 51.230000000000004 ; λ_P = 45.06
# b9 ; λ_B = 40.095 ; λ_P = 22.79
# b9 ; λ_B = 54.86 ; λ_P = 52.32
# b9 ; λ_B = 64.755 ; λ_P = 72.11
# b9 ; λ_B = 49.64 ; λ_P = 41.88
# b9 ; λ_B = 52.504999999999995 ; λ_P = 47.61
# b9 ; λ_B = 70.875 ; λ_P = 84.35
# b9 ; λ_B = 44.415 ; λ_P = 31.43
# b9 ; λ_B = 71.225 ; λ_P = 85.05
# b9 ; λ_B = 68.23 ; λ_P = 79.06
# b9 ; λ_B = 71.65 ; λ_P = 85.9
# b9 ; λ_B = 43.3 ; λ_P = 29.2
# b9 ; λ_B = 54.769999999999996 ; λ_P = 52.14
# w3 we3
# b10 ; λ_B = 9.579999999999998 ; λ_P = -44.94
# b10 ; λ_B = 48.78 ; λ_P = 33.46
# b10 ; λ_B = 59.69 ; λ_P = 55.28
# b10 ; λ_B = 56.199999999999996 ; λ_P = 48.3
# b10 ; λ_B = 71.565 ; λ_P = 79.03
# b10 ; λ_B = 64.37 ; λ_P = 64.64
# b10 ; λ_B = 62.629999999999995 ; λ_P = 61.16
# b10 ; λ_B = 32.055 ; λ_P = 0.01
# b10 ; λ_B = 54.58 ; λ_P = 45.06
# b10 ; λ_B = 43.44499999999999 ; λ_P = 22.79
# b10 ; λ_B = 58.209999999999994 ; λ_P = 52.32
# b10 ; λ_B = 68.10499999999999 ; λ_P = 72.11
# b10 ; λ_B = 52.989999999999995 ; λ_P = 41.88
# b10 ; λ_B = 55.855 ; λ_P = 47.61
# ...
# b3 ; λ_B = 48.349999999999994 ; λ_P = 41.3
# b3 ; λ_B = 68.985 ; λ_P = 82.57
# b3 ; λ_B = 49.06 ; λ_P = 42.72
# b3 ; λ_B = 59.715 ; λ_P = 64.03
# b3 ; λ_B = 56.675 ; λ_P = 57.95
# b3 ; λ_B = 50.515 ; λ_P = 45.63
# b3 ; λ_B = 69.2 ; λ_P = 83.0
# w28 we2
# b4 ; λ_B = 57.635 ; λ_P = 51.17
# b4 ; λ_B = 55.5 ; λ_P = 46.9
# b4 ; λ_B = 67.405 ; λ_P = 70.71
# b4 ; λ_B = 61.589999999999996 ; λ_P = 59.08
# b4 ; λ_B = 58.15 ; λ_P = 52.2
# b4 ; λ_B = 71.04499999999999 ; λ_P = 77.99
# b4 ; λ_B = 63.25 ; λ_P = 62.4
# b4 ; λ_B = 59.4 ; λ_P = 54.7
# b4 ; λ_B = 65.1 ; λ_P = 66.1
# b4 ; λ_B = 61.125 ; λ_P = 58.15
# b4 ; λ_B = 58.084999999999994 ; λ_P = 52.07
# b4 ; λ_B = 67.05 ; λ_P = 70.0
# b4 ; λ_B = 51.425 ; λ_P = 38.75
# b4 ; λ_B = 56.03 ; λ_P = 47.96
# b4 ; λ_B = 52.699999999999996 ; λ_P = 41.3
# b4 ; λ_B = 73.335 ; λ_P = 82.57
# b4 ; λ_B = 53.41 ; λ_P = 42.72
# b4 ; λ_B = 64.065 ; λ_P = 64.03
# b4 ; λ_B = 61.025 ; λ_P = 57.95
# b4 ; λ_B = 54.864999999999995 ; λ_P = 45.63
# b4 ; λ_B = 73.55 ; λ_P = 83.0
# w28 we2
# b7 ; λ_B = 53.935 ; λ_P = 51.17
# b7 ; λ_B = 51.8 ; λ_P = 46.9
# b7 ; λ_B = 63.705 ; λ_P = 70.71
# b7 ; λ_B = 57.89 ; λ_P = 59.08
# b7 ; λ_B = 54.45 ; λ_P = 52.2
# b7 ; λ_B = 67.345 ; λ_P = 77.99
# b7 ; λ_B = 59.55 ; λ_P = 62.4
# b7 ; λ_B = 55.7 ; λ_P = 54.7
# b7 ; λ_B = 61.4 ; λ_P = 66.1
# b7 ; λ_B = 57.425 ; λ_P = 58.15
# b7 ; λ_B = 54.385000000000005 ; λ_P = 52.07
# b7 ; λ_B = 63.35 ; λ_P = 70.0
# b7 ; λ_B = 47.725 ; λ_P = 38.75
# b7 ; λ_B = 52.33 ; λ_P = 47.96
# b7 ; λ_B = 49.0 ; λ_P = 41.3
# b7 ; λ_B = 69.63499999999999 ; λ_P = 82.57
# b7 ; λ_B = 49.71 ; λ_P = 42.72
# b7 ; λ_B = 60.365 ; λ_P = 64.03
# b7 ; λ_B = 57.325 ; λ_P = 57.95
# b7 ; λ_B = 51.165000000000006 ; λ_P = 45.63
# b7 ; λ_B = 69.85 ; λ_P = 83.0
# w28 we2
# b8 ; λ_B = 57.185 ; λ_P = 51.17
# b8 ; λ_B = 55.05 ; λ_P = 46.9
# b8 ; λ_B = 66.955 ; λ_P = 70.71
# b8 ; λ_B = 61.14 ; λ_P = 59.08
# b8 ; λ_B = 57.7 ; λ_P = 52.2
# b8 ; λ_B = 70.595 ; λ_P = 77.99
# b8 ; λ_B = 62.8 ; λ_P = 62.4
# b8 ; λ_B = 58.95 ; λ_P = 54.7
# b8 ; λ_B = 64.65 ; λ_P = 66.1
# b8 ; λ_B = 60.675 ; λ_P = 58.15
# b8 ; λ_B = 57.635000000000005 ; λ_P = 52.07
# b8 ; λ_B = 66.6 ; λ_P = 70.0
# b8 ; λ_B = 50.975 ; λ_P = 38.75
# b8 ; λ_B = 55.58 ; λ_P = 47.96
# b8 ; λ_B = 52.25 ; λ_P = 41.3
# b8 ; λ_B = 72.88499999999999 ; λ_P = 82.57
# b8 ; λ_B = 52.96 ; λ_P = 42.72
# b8 ; λ_B = 63.615 ; λ_P = 64.03
# b8 ; λ_B = 60.575 ; λ_P = 57.95
# b8 ; λ_B = 54.415000000000006 ; λ_P = 45.63
# b8 ; λ_B = 73.1 ; λ_P = 83.0
#
# w28 we3
# b1 ; λ_B = 53.0 ; λ_P = 51.6
# b1 ; λ_B = 58.445 ; λ_P = 62.49
# b1 ; λ_B = 66.36 ; λ_P = 78.32
# b1 ; λ_B = 29.474999999999998 ; λ_P = 4.55
# b1 ; λ_B = 55.17 ; λ_P = 55.94
# b1 ; λ_B = 54.465 ; λ_P = 54.53
# b1 ; λ_B = 28.2 ; λ_P = 2.0
# b1 ; λ_B = 42.805 ; λ_P = 31.21
# b1 ; λ_B = 66.935 ; λ_P = 79.47
# b1 ; λ_B = 65.19 ; λ_P = 75.98
# b1 ; λ_B = 54.15 ; λ_P = 53.9
# b1 ; λ_B = 68.2 ; λ_P = 82.0
# b1 ; λ_B = 22.2 ; λ_P = -10.0
# b1 ; λ_B = 36.1 ; λ_P = 17.8
# b1 ; λ_B = 70.13 ; λ_P = 85.86
# b1 ; λ_B = 68.695 ; λ_P = 82.99
# b1 ; λ_B = 8.84 ; λ_P = -36.72
# b1 ; λ_B = 64.455 ; λ_P = 74.51
# b1 ; λ_B = 42.035 ; λ_P = 29.67
# b1 ; λ_B = 53.695 ; λ_P = 52.99
# b1 ; λ_B = 59.69 ; λ_P = 64.98
# w28 we3
# b2 ; λ_B = 59.849999999999994 ; λ_P = 51.6
# b2 ; λ_B = 65.295 ; λ_P = 62.49
# b2 ; λ_B = 73.21 ; λ_P = 78.32
# b2 ; λ_B = 36.324999999999996 ; λ_P = 4.55
# b2 ; λ_B = 62.019999999999996 ; λ_P = 55.94
# b2 ; λ_B = 61.315 ; λ_P = 54.53
# b2 ; λ_B = 35.05 ; λ_P = 2.0
# b2 ; λ_B = 49.655 ; λ_P = 31.21
# b2 ; λ_B = 73.785 ; λ_P = 79.47
# b2 ; λ_B = 72.03999999999999 ; λ_P = 75.98
# b2 ; λ_B = 61.0 ; λ_P = 53.9
# b2 ; λ_B = 75.05 ; λ_P = 82.0
# b2 ; λ_B = 29.049999999999997 ; λ_P = -10.0
# b2 ; λ_B = 42.949999999999996 ; λ_P = 17.8
# b2 ; λ_B = 76.97999999999999 ; λ_P = 85.86
# b2 ; λ_B = 75.54499999999999 ; λ_P = 82.99
# b2 ; λ_B = 15.689999999999998 ; λ_P = -36.72
# b2 ; λ_B = 71.305 ; λ_P = 74.51
# b2 ; λ_B = 48.885 ; λ_P = 29.67
# b2 ; λ_B = 60.545 ; λ_P = 52.99
# b2 ; λ_B = 66.53999999999999 ; λ_P = 64.98
# w28 we3
# b3 ; λ_B = 53.5 ; λ_P = 51.6
# b3 ; λ_B = 58.945 ; λ_P = 62.49
# b3 ; λ_B = 66.86 ; λ_P = 78.32
# b3 ; λ_B = 29.974999999999998 ; λ_P = 4.55
# b3 ; λ_B = 55.67 ; λ_P = 55.94
# b3 ; λ_B = 54.965 ; λ_P = 54.53
# b3 ; λ_B = 28.7 ; λ_P = 2.0
# b3 ; λ_B = 43.305 ; λ_P = 31.21
# b3 ; λ_B = 67.435 ; λ_P = 79.47
# b3 ; λ_B = 65.69 ; λ_P = 75.98
# b3 ; λ_B = 54.65 ; λ_P = 53.9
# b3 ; λ_B = 68.7 ; λ_P = 82.0
# b3 ; λ_B = 22.7 ; λ_P = -10.0
# b3 ; λ_B = 36.6 ; λ_P = 17.8
# b3 ; λ_B = 70.63 ; λ_P = 85.86
# b3 ; λ_B = 69.195 ; λ_P = 82.99
# b3 ; λ_B = 9.34 ; λ_P = -36.72
# b3 ; λ_B = 64.955 ; λ_P = 74.51
# b3 ; λ_B = 42.535 ; λ_P = 29.67
# b3 ; λ_B = 54.195 ; λ_P = 52.99
# b3 ; λ_B = 60.19 ; λ_P = 64.98
# w28 we3
# b4 ; λ_B = 57.849999999999994 ; λ_P = 51.6
# b4 ; λ_B = 63.295 ; λ_P = 62.49
# b4 ; λ_B = 71.21 ; λ_P = 78.32
# b4 ; λ_B = 34.324999999999996 ; λ_P = 4.55
# b4 ; λ_B = 60.019999999999996 ; λ_P = 55.94
# b4 ; λ_B = 59.315 ; λ_P = 54.53
# b4 ; λ_B = 33.05 ; λ_P = 2.0
# b4 ; λ_B = 47.655 ; λ_P = 31.21
# b4 ; λ_B = 71.785 ; λ_P = 79.47
# b4 ; λ_B = 70.03999999999999 ; λ_P = 75.98
# b4 ; λ_B = 59.0 ; λ_P = 53.9
# b4 ; λ_B = 73.05 ; λ_P = 82.0
# b4 ; λ_B = 27.049999999999997 ; λ_P = -10.0
# b4 ; λ_B = 40.949999999999996 ; λ_P = 17.8
# b4 ; λ_B = 74.97999999999999 ; λ_P = 85.86
# b4 ; λ_B = 73.54499999999999 ; λ_P = 82.99
# b4 ; λ_B = 13.689999999999998 ; λ_P = -36.72
# b4 ; λ_B = 69.305 ; λ_P = 74.51
# b4 ; λ_B = 46.885 ; λ_P = 29.67
# b4 ; λ_B = 58.545 ; λ_P = 52.99
# b4 ; λ_B = 64.53999999999999 ; λ_P = 64.98
# w28 we3
# b9 ; λ_B = 54.5 ; λ_P = 51.6
# b9 ; λ_B = 59.945 ; λ_P = 62.49
# b9 ; λ_B = 67.86 ; λ_P = 78.32
# b9 ; λ_B = 30.974999999999998 ; λ_P = 4.55
# b9 ; λ_B = 56.67 ; λ_P = 55.94
# b9 ; λ_B = 55.965 ; λ_P = 54.53
# b9 ; λ_B = 29.7 ; λ_P = 2.0
# b9 ; λ_B = 44.305 ; λ_P = 31.21
# b9 ; λ_B = 68.435 ; λ_P = 79.47
# b9 ; λ_B = 66.69 ; λ_P = 75.98
# b9 ; λ_B = 55.65 ; λ_P = 53.9
# b9 ; λ_B = 69.7 ; λ_P = 82.0
# b9 ; λ_B = 23.7 ; λ_P = -10.0
# b9 ; λ_B = 37.6 ; λ_P = 17.8
# b9 ; λ_B = 71.63 ; λ_P = 85.86
# b9 ; λ_B = 70.195 ; λ_P = 82.99
# b9 ; λ_B = 10.34 ; λ_P = -36.72
# b9 ; λ_B = 65.955 ; λ_P = 74.51
# b9 ; λ_B = 43.535 ; λ_P = 29.67
# b9 ; λ_B = 55.195 ; λ_P = 52.99
# b9 ; λ_B = 61.19 ; λ_P = 64.98
# w28 we3
# b10 ; λ_B = 57.849999999999994 ; λ_P = 51.6
# b10 ; λ_B = 63.295 ; λ_P = 62.49
# b10 ; λ_B = 71.21 ; λ_P = 78.32
# b10 ; λ_B = 34.324999999999996 ; λ_P = 4.55
# b10 ; λ_B = 60.019999999999996 ; λ_P = 55.94
# b10 ; λ_B = 59.315 ; λ_P = 54.53
# b10 ; λ_B = 33.05 ; λ_P = 2.0
# b10 ; λ_B = 47.655 ; λ_P = 31.21
# b10 ; λ_B = 71.785 ; λ_P = 79.47
# b10 ; λ_B = 70.03999999999999 ; λ_P = 75.98
# b10 ; λ_B = 59.0 ; λ_P = 53.9
# b10 ; λ_B = 73.05 ; λ_P = 82.0
# b10 ; λ_B = 27.049999999999997 ; λ_P = -10.0
# b10 ; λ_B = 40.949999999999996 ; λ_P = 17.8
# b10 ; λ_B = 74.97999999999999 ; λ_P = 85.86
# b10 ; λ_B = 73.54499999999999 ; λ_P = 82.99
# b10 ; λ_B = 13.689999999999998 ; λ_P = -36.72
# b10 ; λ_B = 69.305 ; λ_P = 74.51
# b10 ; λ_B = 46.885 ; λ_P = 29.67
# b10 ; λ_B = 58.545 ; λ_P = 52.99
# b10 ; λ_B = 64.53999999999999 ; λ_P = 64.98
#
# w28 we4
# b1 ; λ_B = 57.364999999999995 ; λ_P = 60.33
# b1 ; λ_B = 56.905 ; λ_P = 59.41
# b1 ; λ_B = 63.035 ; λ_P = 71.67
# b1 ; λ_B = 64.755 ; λ_P = 75.11
# b1 ; λ_B = 58.14 ; λ_P = 61.88
# b1 ; λ_B = 61.025000000000006 ; λ_P = 67.65
# b1 ; λ_B = 54.25 ; λ_P = 54.1
# b1 ; λ_B = 61.67 ; λ_P = 68.94
# b1 ; λ_B = 54.379999999999995 ; λ_P = 54.36
# b1 ; λ_B = 45.7 ; λ_P = 37.0
# b1 ; λ_B = 53.4 ; λ_P = 52.4
# b1 ; λ_B = 63.495000000000005 ; λ_P = 72.59
# b1 ; λ_B = 62.275000000000006 ; λ_P = 70.15
# b1 ; λ_B = 47.144999999999996 ; λ_P = 39.89
# b1 ; λ_B = 72.175 ; λ_P = 89.95
# b1 ; λ_B = 34.295 ; λ_P = 14.19
# b1 ; λ_B = 51.925 ; λ_P = 49.45
# b1 ; λ_B = 60.05 ; λ_P = 65.7
# b1 ; λ_B = 60.0 ; λ_P = 65.6
# b1 ; λ_B = 61.31 ; λ_P = 68.22
# b1 ; λ_B = 60.405 ; λ_P = 66.41
# w28 we4
# b2 ; λ_B = 64.215 ; λ_P = 60.33
# b2 ; λ_B = 63.754999999999995 ; λ_P = 59.41
# b2 ; λ_B = 69.88499999999999 ; λ_P = 71.67
# b2 ; λ_B = 71.60499999999999 ; λ_P = 75.11
# b2 ; λ_B = 64.99 ; λ_P = 61.88
# b2 ; λ_B = 67.875 ; λ_P = 67.65
# b2 ; λ_B = 61.099999999999994 ; λ_P = 54.1
# b2 ; λ_B = 68.52 ; λ_P = 68.94
# b2 ; λ_B = 61.23 ; λ_P = 54.36
# b2 ; λ_B = 52.55 ; λ_P = 37.0
# b2 ; λ_B = 60.25 ; λ_P = 52.4
# b2 ; λ_B = 70.345 ; λ_P = 72.59
# b2 ; λ_B = 69.125 ; λ_P = 70.15
# b2 ; λ_B = 53.995 ; λ_P = 39.89
# b2 ; λ_B = 79.025 ; λ_P = 89.95
# b2 ; λ_B = 41.144999999999996 ; λ_P = 14.19
# b2 ; λ_B = 58.775 ; λ_P = 49.45
# b2 ; λ_B = 66.9 ; λ_P = 65.7
# b2 ; λ_B = 66.85 ; λ_P = 65.6
# b2 ; λ_B = 68.16 ; λ_P = 68.22
# b2 ; λ_B = 67.255 ; λ_P = 66.41
# w28 we4
# b3 ; λ_B = 57.864999999999995 ; λ_P = 60.33
# b3 ; λ_B = 57.405 ; λ_P = 59.41
# b3 ; λ_B = 63.535 ; λ_P = 71.67
# b3 ; λ_B = 65.255 ; λ_P = 75.11
# b3 ; λ_B = 58.64 ; λ_P = 61.88
# b3 ; λ_B = 61.525000000000006 ; λ_P = 67.65
# b3 ; λ_B = 54.75 ; λ_P = 54.1
# b3 ; λ_B = 62.17 ; λ_P = 68.94
# b3 ; λ_B = 54.879999999999995 ; λ_P = 54.36
# b3 ; λ_B = 46.2 ; λ_P = 37.0
# b3 ; λ_B = 53.9 ; λ_P = 52.4
# b3 ; λ_B = 63.995000000000005 ; λ_P = 72.59
# b3 ; λ_B = 62.775000000000006 ; λ_P = 70.15
# b3 ; λ_B = 47.644999999999996 ; λ_P = 39.89
# b3 ; λ_B = 72.675 ; λ_P = 89.95
# b3 ; λ_B = 34.795 ; λ_P = 14.19
# b3 ; λ_B = 52.425 ; λ_P = 49.45
# b3 ; λ_B = 60.55 ; λ_P = 65.7
# b3 ; λ_B = 60.5 ; λ_P = 65.6
# b3 ; λ_B = 61.81 ; λ_P = 68.22
# b3 ; λ_B = 60.905 ; λ_P = 66.41
# w28 we4
# b4 ; λ_B = 62.214999999999996 ; λ_P = 60.33
# b4 ; λ_B = 61.754999999999995 ; λ_P = 59.41
# b4 ; λ_B = 67.88499999999999 ; λ_P = 71.67
# b4 ; λ_B = 69.60499999999999 ; λ_P = 75.11
# b4 ; λ_B = 62.989999999999995 ; λ_P = 61.88
# b4 ; λ_B = 65.875 ; λ_P = 67.65
# b4 ; λ_B = 59.099999999999994 ; λ_P = 54.1
# b4 ; λ_B = 66.52 ; λ_P = 68.94
# b4 ; λ_B = 59.23 ; λ_P = 54.36
# b4 ; λ_B = 50.55 ; λ_P = 37.0
# b4 ; λ_B = 58.25 ; λ_P = 52.4
# b4 ; λ_B = 68.345 ; λ_P = 72.59
# b4 ; λ_B = 67.125 ; λ_P = 70.15
# b4 ; λ_B = 51.995 ; λ_P = 39.89
# b4 ; λ_B = 77.025 ; λ_P = 89.95
# b4 ; λ_B = 39.144999999999996 ; λ_P = 14.19
# b4 ; λ_B = 56.775 ; λ_P = 49.45
# b4 ; λ_B = 64.9 ; λ_P = 65.7
# b4 ; λ_B = 64.85 ; λ_P = 65.6
# b4 ; λ_B = 66.16 ; λ_P = 68.22
# b4 ; λ_B = 65.255 ; λ_P = 66.41
# w28 we4
# b11 ; λ_B = 59.065 ; λ_P = 60.33
# b11 ; λ_B = 58.605 ; λ_P = 59.41
# b11 ; λ_B = 64.735 ; λ_P = 71.67
# b11 ; λ_B = 66.455 ; λ_P = 75.11
# b11 ; λ_B = 59.84 ; λ_P = 61.88
# b11 ; λ_B = 62.725 ; λ_P = 67.65
# b11 ; λ_B = 55.95 ; λ_P = 54.1
# b11 ; λ_B = 63.37 ; λ_P = 68.94
# b11 ; λ_B = 56.08 ; λ_P = 54.36
# b11 ; λ_B = 47.4 ; λ_P = 37.0
# b11 ; λ_B = 55.099999999999994 ; λ_P = 52.4
# b11 ; λ_B = 65.195 ; λ_P = 72.59
# b11 ; λ_B = 63.975 ; λ_P = 70.15
# b11 ; λ_B = 48.845 ; λ_P = 39.89
# b11 ; λ_B = 73.875 ; λ_P = 89.95
# b11 ; λ_B = 35.995 ; λ_P = 14.19
# b11 ; λ_B = 53.625 ; λ_P = 49.45
# b11 ; λ_B = 61.75 ; λ_P = 65.7
# b11 ; λ_B = 61.699999999999996 ; λ_P = 65.6
# b11 ; λ_B = 63.01 ; λ_P = 68.22
# b11 ; λ_B = 62.105 ; λ_P = 66.41
# w28 we4
# b12 ; λ_B = 62.365 ; λ_P = 60.33
# b12 ; λ_B = 61.905 ; λ_P = 59.41
# b12 ; λ_B = 68.035 ; λ_P = 71.67
# b12 ; λ_B = 69.755 ; λ_P = 75.11
# b12 ; λ_B = 63.14 ; λ_P = 61.88
# b12 ; λ_B = 66.025 ; λ_P = 67.65
# b12 ; λ_B = 59.25 ; λ_P = 54.1
# b12 ; λ_B = 66.67 ; λ_P = 68.94
# b12 ; λ_B = 59.38 ; λ_P = 54.36
# b12 ; λ_B = 50.7 ; λ_P = 37.0
# b12 ; λ_B = 58.400000000000006 ; λ_P = 52.4
# b12 ; λ_B = 68.495 ; λ_P = 72.59
# b12 ; λ_B = 67.275 ; λ_P = 70.15
# b12 ; λ_B = 52.145 ; λ_P = 39.89
# b12 ; λ_B = 77.17500000000001 ; λ_P = 89.95
# b12 ; λ_B = 39.295 ; λ_P = 14.19
# b12 ; λ_B = 56.925000000000004 ; λ_P = 49.45
# b12 ; λ_B = 65.05000000000001 ; λ_P = 65.7
# b12 ; λ_B = 65.0 ; λ_P = 65.6
# b12 ; λ_B = 66.31 ; λ_P = 68.22
# b12 ; λ_B = 65.405 ; λ_P = 66.41
#
# w29 we1
# b1 ; λ_B = 51.11 ; λ_P = 47.82
# b1 ; λ_B = 56.254999999999995 ; λ_P = 58.11
# b1 ; λ_B = 67.2 ; λ_P = 80.0
# b1 ; λ_B = 38.635 ; λ_P = 22.87
# b1 ; λ_B = 52.644999999999996 ; λ_P = 50.89
# b1 ; λ_B = 56.525 ; λ_P = 58.65
# b1 ; λ_B = 51.65 ; λ_P = 48.9
# b1 ; λ_B = 57.015 ; λ_P = 59.63
# b1 ; λ_B = 18.92 ; λ_P = -16.56
# b1 ; λ_B = 63.06 ; λ_P = 71.72
# b1 ; λ_B = 53.905 ; λ_P = 53.41
# b1 ; λ_B = 48.7 ; λ_P = 43.0
# b1 ; λ_B = 40.015 ; λ_P = 25.63
# b1 ; λ_B = 42.655 ; λ_P = 30.91
# b1 ; λ_B = 73.605 ; λ_P = 92.81
# b1 ; λ_B = 74.125 ; λ_P = 93.85
# b1 ; λ_B = 68.17999999999999 ; λ_P = 81.96
# b1 ; λ_B = 61.545 ; λ_P = 68.69
# b1 ; λ_B = 59.265 ; λ_P = 64.13
# b1 ; λ_B = 59.144999999999996 ; λ_P = 63.89
# b1 ; λ_B = 61.364999999999995 ; λ_P = 68.33
# w29 we1
# b2 ; λ_B = 57.959999999999994 ; λ_P = 47.82
# b2 ; λ_B = 63.105 ; λ_P = 58.11
# b2 ; λ_B = 74.05 ; λ_P = 80.0
# b2 ; λ_B = 45.485 ; λ_P = 22.87
# b2 ; λ_B = 59.495 ; λ_P = 50.89
# b2 ; λ_B = 63.375 ; λ_P = 58.65
# b2 ; λ_B = 58.5 ; λ_P = 48.9
# b2 ; λ_B = 63.864999999999995 ; λ_P = 59.63
# b2 ; λ_B = 25.769999999999996 ; λ_P = -16.56
# b2 ; λ_B = 69.91 ; λ_P = 71.72
# b2 ; λ_B = 60.754999999999995 ; λ_P = 53.41
# b2 ; λ_B = 55.55 ; λ_P = 43.0
# b2 ; λ_B = 46.864999999999995 ; λ_P = 25.63
# b2 ; λ_B = 49.504999999999995 ; λ_P = 30.91
# b2 ; λ_B = 80.455 ; λ_P = 92.81
# b2 ; λ_B = 80.975 ; λ_P = 93.85
# b2 ; λ_B = 75.03 ; λ_P = 81.96
# b2 ; λ_B = 68.395 ; λ_P = 68.69
# b2 ; λ_B = 66.115 ; λ_P = 64.13
# b2 ; λ_B = 65.995 ; λ_P = 63.89
# b2 ; λ_B = 68.215 ; λ_P = 68.33
# w29 we1
# b3 ; λ_B = 51.61 ; λ_P = 47.82
# b3 ; λ_B = 56.754999999999995 ; λ_P = 58.11
# b3 ; λ_B = 67.7 ; λ_P = 80.0
# b3 ; λ_B = 39.135 ; λ_P = 22.87
# b3 ; λ_B = 53.144999999999996 ; λ_P = 50.89
# b3 ; λ_B = 57.025 ; λ_P = 58.65
# b3 ; λ_B = 52.15 ; λ_P = 48.9
# b3 ; λ_B = 57.515 ; λ_P = 59.63
# b3 ; λ_B = 19.42 ; λ_P = -16.56
# b3 ; λ_B = 63.56 ; λ_P = 71.72
# b3 ; λ_B = 54.405 ; λ_P = 53.41
# b3 ; λ_B = 49.2 ; λ_P = 43.0
# b3 ; λ_B = 40.515 ; λ_P = 25.63
# b3 ; λ_B = 43.155 ; λ_P = 30.91
# b3 ; λ_B = 74.105 ; λ_P = 92.81
# b3 ; λ_B = 74.625 ; λ_P = 93.85
# b3 ; λ_B = 68.67999999999999 ; λ_P = 81.96
# b3 ; λ_B = 62.045 ; λ_P = 68.69
# b3 ; λ_B = 59.765 ; λ_P = 64.13
# b3 ; λ_B = 59.644999999999996 ; λ_P = 63.89
# b3 ; λ_B = 61.864999999999995 ; λ_P = 68.33
# w29 we1
# b4 ; λ_B = 55.959999999999994 ; λ_P = 47.82
# b4 ; λ_B = 61.105 ; λ_P = 58.11
# b4 ; λ_B = 72.05 ; λ_P = 80.0
# b4 ; λ_B = 43.485 ; λ_P = 22.87
# b4 ; λ_B = 57.495 ; λ_P = 50.89
# b4 ; λ_B = 61.375 ; λ_P = 58.65
# b4 ; λ_B = 56.5 ; λ_P = 48.9
# b4 ; λ_B = 61.864999999999995 ; λ_P = 59.63
# b4 ; λ_B = 23.769999999999996 ; λ_P = -16.56
# b4 ; λ_B = 67.91 ; λ_P = 71.72
# b4 ; λ_B = 58.754999999999995 ; λ_P = 53.41
# b4 ; λ_B = 53.55 ; λ_P = 43.0
# b4 ; λ_B = 44.864999999999995 ; λ_P = 25.63
# b4 ; λ_B = 47.504999999999995 ; λ_P = 30.91
# b4 ; λ_B = 78.455 ; λ_P = 92.81
# b4 ; λ_B = 78.975 ; λ_P = 93.85
# b4 ; λ_B = 73.03 ; λ_P = 81.96
# b4 ; λ_B = 66.395 ; λ_P = 68.69
# b4 ; λ_B = 64.115 ; λ_P = 64.13
# b4 ; λ_B = 63.995 ; λ_P = 63.89
# b4 ; λ_B = 66.215 ; λ_P = 68.33
# w29 we1
# b5 ; λ_B = 46.86 ; λ_P = 47.82
# b5 ; λ_B = 52.004999999999995 ; λ_P = 58.11
# b5 ; λ_B = 62.95 ; λ_P = 80.0
# b5 ; λ_B = 34.385 ; λ_P = 22.87
# Excessive output truncated after 524294 bytes.
# b5 ; λ_B = 48.394999999999996 ; λ_P = 50.89
# b5 ; λ_B = 52.275 ; λ_P = 58.65
# b5 ; λ_B = 47.4 ; λ_P = 48.9
# b5 ; λ_B = 52.765 ; λ_P = 59.63
# b5 ; λ_B = 14.67 ; λ_P = -16.56
# b5 ; λ_B = 58.81 ; λ_P = 71.72
# b5 ; λ_B = 49.655 ; λ_P = 53.41
# b5 ; λ_B = 44.45 ; λ_P = 43.0
# b5 ; λ_B = 35.765 ; λ_P = 25.63
# b5 ; λ_B = 38.405 ; λ_P = 30.91
# b5 ; λ_B = 69.355 ; λ_P = 92.81
# b5 ; λ_B = 69.875 ; λ_P = 93.85
# b5 ; λ_B = 63.92999999999999 ; λ_P = 81.96
# b5 ; λ_B = 57.295 ; λ_P = 68.69
# b5 ; λ_B = 55.015 ; λ_P = 64.13
# b5 ; λ_B = 54.894999999999996 ; λ_P = 63.89
# b5 ; λ_B = 57.114999999999995 ; λ_P = 68.33
# w29 we1
# b6 ; λ_B = 51.91 ; λ_P = 47.82
# b6 ; λ_B = 57.055 ; λ_P = 58.11
# b6 ; λ_B = 68.0 ; λ_P = 80.0
# b6 ; λ_B = 39.435 ; λ_P = 22.87
# b6 ; λ_B = 53.445 ; λ_P = 50.89
# b6 ; λ_B = 57.325 ; λ_P = 58.65
# b6 ; λ_B = 52.45 ; λ_P = 48.9
# b6 ; λ_B = 57.815 ; λ_P = 59.63
# b6 ; λ_B = 19.72 ; λ_P = -16.56
# b6 ; λ_B = 63.86 ; λ_P = 71.72
# b6 ; λ_B = 54.705 ; λ_P = 53.41
# b6 ; λ_B = 49.5 ; λ_P = 43.0
# b6 ; λ_B = 40.815 ; λ_P = 25.63
# b6 ; λ_B = 43.455 ; λ_P = 30.91
# b6 ; λ_B = 74.405 ; λ_P = 92.81
# b6 ; λ_B = 74.925 ; λ_P = 93.85
# b6 ; λ_B = 68.97999999999999 ; λ_P = 81.96
# b6 ; λ_B = 62.345 ; λ_P = 68.69
# b6 ; λ_B = 60.065 ; λ_P = 64.13
# b6 ; λ_B = 59.945 ; λ_P = 63.89
# b6 ; λ_B = 62.165 ; λ_P = 68.33
#
# w29 we2
# b1 ; λ_B = 49.72 ; λ_P = 45.04
# b1 ; λ_B = 48.224999999999994 ; λ_P = 42.05
# b1 ; λ_B = 65.39 ; λ_P = 76.38
# b1 ; λ_B = 27.36 ; λ_P = 0.32
# b1 ; λ_B = 53.474999999999994 ; λ_P = 52.55
# b1 ; λ_B = 67.665 ; λ_P = 80.93
# b1 ; λ_B = 48.14 ; λ_P = 41.88
# b1 ; λ_B = 68.355 ; λ_P = 82.31
# b1 ; λ_B = 58.129999999999995 ; λ_P = 61.86
# b1 ; λ_B = 73.975 ; λ_P = 93.55
# b1 ; λ_B = 69.25 ; λ_P = 84.1
# b1 ; λ_B = 69.65 ; λ_P = 84.9
# b1 ; λ_B = 44.97 ; λ_P = 35.54
# b1 ; λ_B = 57.379999999999995

# %%
result = Dict()
println("OV = ", objective_value(co_pv))
for w in W_PP    
    println()
    print(w, ": ")
    for week in WEEK
        println()
        for b in Bt[week]
            print(b, " = ", value(PB[b,w]), " ")
        end
        for t in week_to_hour[week]
            #print("EP", " = ", value(EP[t,w]), " ")
        end
    end
end
# Out:
# OV = 1.074215869453067e7
#
# w1:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w2:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w3:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w4:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w5:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w6:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w7:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 50.0 b12 = 0.0
# w8:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 50.0 b12 = 0.0
# w9:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w10:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w11:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 50.0 b12 = 0.0
# w12:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 50.0 b12 = 0.0
# w13:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 50.0 b12 = 0.0
# w14:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 50.0 b12 = 0.0
# w15:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w16:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w17:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w18:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w19:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w20:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w21:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w22:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w23:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w24:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w25:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w26:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w27:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 50.0 b12 = 0.0
# w28:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 50.0 b12 = 0.0
# w29:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w30:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w31:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w32:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w33:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w34:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w35:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w36:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 50.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w37:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w38:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w39:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w40:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w41:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w42:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w43:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w44:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 0.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w45:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w46:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w47:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0
# w48:
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b5 = 50.0 b6 = 40.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b7 = 0.0 b8 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b9 = 50.0 b10 = 0.0
# b1 = 30.0 b2 = 0.0 b3 = 30.0 b4 = 0.0 b11 = 0.0 b12 = 0.0

# %%
# visualization of Power purchased from bilateral contracts
x1 = Vector{Float64}()  

for b in B
    append!(x1, value.(PB[b,"w1"]))
end
PB1 = sum(value.(PB[b,"w1"]) for b in B)

x2 = Vector{Float64}()  

for b in B
    append!(x2, value.(PB[b,"w9"]))
end
PB2 = sum(value.(PB[b,"w9"]) for b in B)
display(plot(Array{Int}(1:length(x1)),x1))
display(plot(Array{Int}(1:length(x2)),x2))
println("Power purchased from bilateral contracts: ", PB1)
println("Power purchased from bilateral contracts: ", PB2)
# Out:
# Power purchased from bilateral contracts: 150.0
# Power purchased from bilateral contracts: 150.0

# %%
objective_value(co_pv)
# Out:
# 1.074215869453067e7
